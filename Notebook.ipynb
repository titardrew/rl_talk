# %% [markdown]
# <a href="https://colab.research.google.com/github/titardrew/rl_talk/blob/main/Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
import io
import base64
import random
import sys

# %%
# !git clone https://github.com/titardrew/rl_talk.git > /dev/null 2>&1 
# !pip install -r rl_talk/requirements.txt > /dev/null 2>&1 
# !apt-get install x11-utils > /dev/null 2>&1 
# !pip install pyglet > /dev/null 2>&1 
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !pip install 'gym[all]' > /dev/null 2>&1
sys.path.append(str(Path(".") / "rl_talk"))

# %%
import gym
from gym import wrappers
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import torch

from lib import get_network
from lib.agent import DQN
from lib.logging import Logger
from lib.rollout import ReplayBuffer

from IPython.display import HTML
from IPython import display as ipythondisplay

plt.style.use('seaborn')

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start();

# %% [markdown]
# ### We use PyTorch for neural networks. If you are new to PyTorch see tutorials:
# https://pytorch.org/tutorials/ <br>
# https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html

# %% [markdown]
# # CartPole

# %% [markdown]
# First, let's take a closer look at the environment.

# %%
def make_env(name, seed=None, monitor=False):
    env = gym.make(name)
    if monitor:
        env = wrappers.Monitor(env, "./gym-results", force=True)
    if seed:
        env.seed(seed)
    return env

# %%
def get_html_video_string(infix):
    video = io.open(
        f'./gym-results/openaigym.video.{infix}.video000000.mp4',
        'r+b').read()
    encoded = base64.b64encode(video)
    dec_str = encoded.decode('ascii')
    src_tag = f'<source src="data:video/mp4;base64,{dec_str}" type="video/mp4" /></video>'
    html = f'<video width="360" height="auto" alt="test" controls>{src_tag}</video>'
    return html

# %%
SEED = 0xCEEEEEEB
random.seed(SEED)
torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
log_root = Path("results")
log_root.mkdir(exist_ok=True)

# %% [markdown]
# The next cell will embed a video of random policy playing CartPole-v1

# %%
env = make_env("CartPole-v1", monitor=True)
env.observation_space, env.action_space
# Out:
# (Box(4,), Discrete(2))

# %%
env = make_env("CartPole-v1", monitor=True)
env.reset()
while True:
    action = env.action_space.sample()
    if env.step(action)[2]: break
env.close()

HTML(data=get_html_video_string(env.file_infix))
# Out:
# <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video></video>

# %% [markdown]
# ## Training loop
#
# The loop consists of:
# * Picking an action using the policy:
# $$a = \text{argmax}_a Q(s, a)$$
# * Sending the action to environment (`step`)
# * Sampling N examples from the ReplayBuffer:
# $$ (s_i, a_i, s^\prime_i, r_i)_{i=1,..,N} $$
# * Updating Q-network by minimizing the loss:
# $$y = r_i + \gamma \text{max}_a Q_{target}(s^{\prime}_i, a)$$
#
# $$L_i = \text{Loss}(Q(s_i, a_i), y)$$
# $$L = \frac{1}{N} \sum_i L_i \rightarrow min,$$
# where $\text{Loss}$ is $L_2$ loss or Huber loss
# * Updating target network every `target_update_every` iteration:
# $$\theta^\prime \leftarrow \theta \tau + \theta^\prime (1 - \tau)$$
# where $\theta^\prime$ - paremeters of $Q_{target}$ network, <br>
# $\theta$ - paremeters of $Q$ network,<br>
# $\tau \in [0, 1]$
#
# Note, that we also use a logger that writes training info to `CSV` file, `TensorBoard` and `stdout`. We use `CSV` and `stdout` throughout the notebook, but you can use TB for convenience.

# %%
def train(
    agent,
    env,
    *,
    log_dir,
    prefix,
    buffer_size,
    n_steps,
    warmup_steps,
    target_update_every,
    log_every,
    save_every,
    update_every=1
):
    """Training loop procedure.
    
    Arguments:
        agent: DQN object.
        env: Gym environment.
        log_dir: PathLib path to logging dir.
        prefix: Prefix for the experiment.
        buffer_size: Maximum capacity of the replay buffer.
        n_steps: Total number of training iterations.
        warmup_steps: Number of first iterations that employ random policy.
        target_update_every: Number of iterations between target network updates.
        log_every: Log frequency
        save_every: Save frequency
        
    Returns the best agent after training.
    """
    best_agent = agent.copy()
    best_rew = -np.inf
    
    logger = Logger(log_dir, prefix)
    episode_reward = []
    memory = ReplayBuffer(buffer_size)
    
    obs_cur = env.reset()
    for i in range(n_steps + 1):
        if i > warmup_steps:
            obs = torch.FloatTensor(obs_cur).unsqueeze(0)
            act = agent.pick_action(obs)
        else:
            act = env.action_space.sample()

        obs_prev = obs_cur
        obs_cur, rew, done, info = env.step(act)
        episode_reward.append(rew)

        memory.push(obs_prev, act, obs_cur, rew, done)

        if done:
            rew = np.sum(episode_reward)
            episode_reward = []
            logger.log_arr_kv("reward/reward", rew)
            obs_cur = env.reset()

        if i > warmup_steps:

            if i % update_every == 0:
                loss, q, q_est = agent.update_value(memory)
                logger.log_arr_kv("loss/bellman_error_t", loss)
                logger.log_arr_kv("misc/q_t", q)
                logger.log_arr_kv("misc/q_est_t", q_est)

            if i % target_update_every == 0:
                agent.update_target()

            if i % log_every == 0:
                rew = logger.reduce_arr_kv("reward/reward", "reward/reward_mean", np.mean)
                if rew > best_rew:
                    best_agent = agent.copy()
                
                logger.reduce_arr_kv("reward/reward", "reward/reward_max", np.max)
                logger.reduce_arr_kv("reward/reward", "reward/reward_min", np.min)
                logger.reduce_arr_kv("reward/reward", "reward/reward_std", np.std)
                logger.reduce_arr_kv("loss/bellman_error_t", "loss/bellman_error", np.mean)
                logger.reduce_arr_kv("misc/q_t", "misc/q", np.mean)
                logger.reduce_arr_kv("misc/q_est_t", "misc/q_est", np.mean)
                logger.log_kv("misc/epsilon", agent.eps)
                logger.log_kv("misc/timestep", i)
                logger.write_logs(skip_arrs=True)
                
                

            if i % save_every == 0:
                num = i // save_every + 1
                save_dir = log_dir / "checkpoints"
                save_dir.mkdir(exist_ok=True)
                agent.save_to(save_dir, prefix=hex(num)[2:].upper())

        agent.update_eps()
    return best_agent

# %% [markdown]
# # Implementation
#
# Now, run the next two cells. You should obtain the highest (500) reward in less than 100000 steps

# %% [markdown]
# Note! You can try to use small `target_update_every`. E.g. value of 1 corresponds to fitted Q-iteration. The expected outcome is unstable or even divergent behaviour

# %%
env = make_env("CartPole-v1", SEED)
env.action_space, env.observation_space
# Out:
# (Discrete(2), Box(4,))

# %%
value_network = get_network("mlp")(
    env.observation_space.shape[0],
    64,
    env.action_space.n)

agent = DQN(
    value_network,
    env.action_space,
    eps=.2,
    eps_decay=(.2 - .02) / 10**5,
    batch_size=32,
    learning_rate=5e-4,
    discount_factor=.99,
    # cuda=True
)

# %%
agent = train(
    agent,
    env,
    log_dir=log_root / "cartpole-v1",
    prefix="_dqn",
    buffer_size=5 * 10**4,
    n_steps=10**5,
    warmup_steps=1000,
    target_update_every=500,
    log_every=500,
    save_every=1000,
    update_every=1
)
# Out:
# rl_talk/lib/agent.py:93: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   v_s0 = FloatTensor(v_s0)
# ---------------------------------
# | reward/reward_mean | 16.578   |
# | reward/reward_max  | 59       |
# | reward/reward_min  | 8        |
# | reward/reward_std  | 8.8179   |
# | loss/bellman_error | 0.085846 |
# | misc/q             | 1.1403   |
# | misc/q_est         | 0.90409  |
# | misc/epsilon       | 0.1973   |
# | misc/timestep      | 1500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 11.545   |
# | reward/reward_max  | 15       |
# | reward/reward_min  | 9        |
# | reward/reward_std  | 1.6713   |
# | loss/bellman_error | 0.063087 |
# | misc/q             | 2.0853   |
# | misc/q_est         | 2.022    |
# | misc/epsilon       | 0.1964   |
# | misc/timestep      | 2000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 12.564   |
# | reward/reward_max  | 19       |
# | reward/reward_min  | 9        |
# | reward/reward_std  | 2.3944   |
# | loss/bellman_error | 0.10105  |
# | misc/q             | 2.9499   |
# | misc/q_est         | 2.9541   |
# | misc/epsilon       | 0.1955   |
# | misc/timestep      | 2500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 16.933   |
# | reward/reward_max  | 25       |
# | reward/reward_min  | 11       |
# | reward/reward_std  | 3.8029   |
# | loss/bellman_error | 0.13118  |
# | misc/q             | 3.8148   |
# | misc/q_est         | 3.8684   |
# | misc/epsilon       | 0.1946   |
# | misc/timestep      | 3000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 21.565   |
# | reward/reward_max  | 47       |
# | reward/reward_min  | 13       |
# | reward/reward_std  | 7.3178   |
# | loss/bellman_error | 0.1665   |
# | misc/q             | 4.6452   |
# | misc/q_est         | 4.7417   |
# | misc/epsilon       | 0.1937   |
# | misc/timestep      | 3500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 27.667   |
# | reward/reward_max  | 73       |
# | reward/reward_min  | 14       |
# | reward/reward_std  | 13.581   |
# | loss/bellman_error | 0.18119  |
# | misc/q             | 5.474    |
# | misc/q_est         | 5.5905   |
# | misc/epsilon       | 0.1928   |
# | misc/timestep      | 4000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 25.684   |
# | reward/reward_max  | 42       |
# | reward/reward_min  | 18       |
# | reward/reward_std  | 6.6098   |
# | loss/bellman_error | 0.2173   |
# | misc/q             | 6.356    |
# | misc/q_est         | 6.5124   |
# | misc/epsilon       | 0.1919   |
# | misc/timestep      | 4500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 31.125   |
# | reward/reward_max  | 45       |
# | reward/reward_min  | 22       |
# | reward/reward_std  | 6.8179   |
# | loss/bellman_error | 0.22497  |
# | misc/q             | 7.1432   |
# | misc/q_est         | 7.3149   |
# | misc/epsilon       | 0.191    |
# | misc/timestep      | 5000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 49.222   |
# | reward/reward_max  | 107      |
# | reward/reward_min  | 23       |
# | reward/reward_std  | 24.517   |
# | loss/bellman_error | 0.24685  |
# | misc/q             | 7.9612   |
# | misc/q_est         | 8.1549   |
# | misc/epsilon       | 0.1901   |
# | misc/timestep      | 5500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 78.143   |
# | reward/reward_max  | 109      |
# | reward/reward_min  | 58       |
# | reward/reward_std  | 16.89    |
# | loss/bellman_error | 0.25132  |
# | misc/q             | 8.8705   |
# | misc/q_est         | 9.073    |
# | misc/epsilon       | 0.1892   |
# | misc/timestep      | 6000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 67       |
# | reward/reward_max  | 99       |
# | reward/reward_min  | 40       |
# | reward/reward_std  | 19.079   |
# | loss/bellman_error | 0.28754  |
# | misc/q             | 9.7054   |
# | misc/q_est         | 9.9429   |
# | misc/epsilon       | 0.1883   |
# | misc/timestep      | 6500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 78.857   |
# | reward/reward_max  | 184      |
# | reward/reward_min  | 47       |
# | reward/reward_std  | 45.649   |
# | loss/bellman_error | 0.28739  |
# | misc/q             | 10.617   |
# | misc/q_est         | 10.86    |
# | misc/epsilon       | 0.1874   |
# | misc/timestep      | 7000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 37.231   |
# | reward/reward_max  | 49       |
# | reward/reward_min  | 24       |
# | reward/reward_std  | 7.5971   |
# | loss/bellman_error | 0.31198  |
# | misc/q             | 11.495   |
# | misc/q_est         | 11.76    |
# | misc/epsilon       | 0.1865   |
# | misc/timestep      | 7500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 28.222   |
# | reward/reward_max  | 58       |
# | reward/reward_min  | 15       |
# | reward/reward_std  | 10.581   |
# | loss/bellman_error | 0.35872  |
# | misc/q             | 12.488   |
# | misc/q_est         | 12.801   |
# | misc/epsilon       | 0.1856   |
# | misc/timestep      | 8000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 20.8     |
# | reward/reward_max  | 31       |
# | reward/reward_min  | 14       |
# | reward/reward_std  | 3.8575   |
# | loss/bellman_error | 0.3778   |
# | misc/q             | 13.46    |
# | misc/q_est         | 13.792   |
# | misc/epsilon       | 0.1847   |
# | misc/timestep      | 8500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 14.2     |
# | reward/reward_max  | 25       |
# | reward/reward_min  | 10       |
# | reward/reward_std  | 2.8163   |
# | loss/bellman_error | 0.45065  |
# | misc/q             | 14.454   |
# | misc/q_est         | 14.86    |
# | misc/epsilon       | 0.1838   |
# | misc/timestep      | 9000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 13.611   |
# | reward/reward_max  | 26       |
# | reward/reward_min  | 9        |
# | reward/reward_std  | 3.1735   |
# | loss/bellman_error | 0.52026  |
# | misc/q             | 15.409   |
# | misc/q_est         | 15.882   |
# | misc/epsilon       | 0.1829   |
# | misc/timestep      | 9500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 12.048   |
# | reward/reward_max  | 16       |
# | reward/reward_min  | 9        |
# | reward/reward_std  | 1.7451   |
# | loss/bellman_error | 0.62593  |
# | misc/q             | 16.274   |
# | misc/q_est         | 16.849   |
# | misc/epsilon       | 0.182    |
# | misc/timestep      | 10000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 12.171   |
# | reward/reward_max  | 17       |
# | reward/reward_min  | 9        |
# | reward/reward_std  | 1.7236   |
# | loss/bellman_error | 0.69994  |
# | misc/q             | 17.156   |
# | misc/q_est         | 17.805   |
# | misc/epsilon       | 0.1811   |
# | misc/timestep      | 10500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 11.5     |
# | reward/reward_max  | 17       |
# | reward/reward_min  | 8        |
# | reward/reward_std  | 1.7255   |
# | loss/bellman_error | 0.75258  |
# | misc/q             | 18.18    |
# | misc/q_est         | 18.88    |
# | misc/epsilon       | 0.1802   |
# | misc/timestep      | 11000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 10.396   |
# | reward/reward_max  | 16       |
# | reward/reward_min  | 8        |
# | reward/reward_std  | 1.5644   |
# | loss/bellman_error | 0.85438  |
# | misc/q             | 19.09    |
# | misc/q_est         | 19.893   |
# | misc/epsilon       | 0.1793   |
# | misc/timestep      | 11500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 10.66    |
# | reward/reward_max  | 14       |
# | reward/reward_min  | 8        |
# | reward/reward_std  | 1.5882   |
# | loss/bellman_error | 0.92821  |
# | misc/q             | 19.963   |
# | misc/q_est         | 20.839   |
# | misc/epsilon       | 0.1784   |
# | misc/timestep      | 12000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 10       |
# | reward/reward_max  | 13       |
# | reward/reward_min  | 8        |
# | reward/reward_std  | 1.2      |
# | loss/bellman_error | 1.0899   |
# | misc/q             | 20.745   |
# | misc/q_est         | 21.778   |
# | misc/epsilon       | 0.1775   |
# | misc/timestep      | 12500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 11.111   |
# | reward/reward_max  | 19       |
# | reward/reward_min  | 8        |
# | reward/reward_std  | 2.3965   |
# | loss/bellman_error | 1.0932   |
# | misc/q             | 21.678   |
# | misc/q_est         | 22.717   |
# | misc/epsilon       | 0.1766   |
# | misc/timestep      | 13000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 22.818   |
# | reward/reward_max  | 54       |
# | reward/reward_min  | 9        |
# | reward/reward_std  | 13.983   |
# | loss/bellman_error | 1.1013   |
# | misc/q             | 22.507   |
# | misc/q_est         | 23.556   |
# | misc/epsilon       | 0.1757   |
# | misc/timestep      | 13500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 44.364   |
# | reward/reward_max  | 69       |
# | reward/reward_min  | 9        |
# | reward/reward_std  | 23.023   |
# | loss/bellman_error | 1.1176   |
# | misc/q             | 23.289   |
# | misc/q_est         | 24.355   |
# | misc/epsilon       | 0.1748   |
# | misc/timestep      | 14000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 73       |
# | reward/reward_max  | 91       |
# | reward/reward_min  | 56       |
# | reward/reward_std  | 10.708   |
# | loss/bellman_error | 1.1884   |
# | misc/q             | 23.989   |
# | misc/q_est         | 25.125   |
# | misc/epsilon       | 0.1739   |
# | misc/timestep      | 14500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 95.6     |
# | reward/reward_max  | 153      |
# | reward/reward_min  | 78       |
# | reward/reward_std  | 28.793   |
# | loss/bellman_error | 1.1301   |
# | misc/q             | 24.775   |
# | misc/q_est         | 25.855   |
# | misc/epsilon       | 0.173    |
# | misc/timestep      | 15000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 167      |
# | reward/reward_max  | 173      |
# | reward/reward_min  | 162      |
# | reward/reward_std  | 4.5461   |
# | loss/bellman_error | 1.188    |
# | misc/q             | 25.528   |
# | misc/q_est         | 26.665   |
# | misc/epsilon       | 0.1721   |
# | misc/timestep      | 15500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 162.67   |
# | reward/reward_max  | 202      |
# | reward/reward_min  | 135      |
# | reward/reward_std  | 28.57    |
# | loss/bellman_error | 1.0745   |
# | misc/q             | 26.376   |
# | misc/q_est         | 27.404   |
# | misc/epsilon       | 0.1712   |
# | misc/timestep      | 16000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 134.5    |
# | reward/reward_max  | 152      |
# | reward/reward_min  | 122      |
# | reward/reward_std  | 10.897   |
# | loss/bellman_error | 1.1868   |
# | misc/q             | 27.006   |
# | misc/q_est         | 28.142   |
# | misc/epsilon       | 0.1703   |
# | misc/timestep      | 16500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 134      |
# | reward/reward_max  | 148      |
# | reward/reward_min  | 119      |
# | reward/reward_std  | 12.669   |
# | loss/bellman_error | 1.1279   |
# | misc/q             | 27.844   |
# | misc/q_est         | 28.923   |
# | misc/epsilon       | 0.1694   |
# | misc/timestep      | 17000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 111      |
# | reward/reward_max  | 138      |
# | reward/reward_min  | 73       |
# | reward/reward_std  | 23.654   |
# | loss/bellman_error | 1.1068   |
# | misc/q             | 28.67    |
# | misc/q_est         | 29.729   |
# | misc/epsilon       | 0.1685   |
# | misc/timestep      | 17500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 122.5    |
# | reward/reward_max  | 154      |
# | reward/reward_min  | 104      |
# | reward/reward_std  | 19.164   |
# | loss/bellman_error | 1.1156   |
# | misc/q             | 29.351   |
# | misc/q_est         | 30.418   |
# | misc/epsilon       | 0.1676   |
# | misc/timestep      | 18000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 112.8    |
# | reward/reward_max  | 132      |
# | reward/reward_min  | 87       |
# | reward/reward_std  | 17.034   |
# | loss/bellman_error | 1.1613   |
# | misc/q             | 30.076   |
# | misc/q_est         | 31.188   |
# | misc/epsilon       | 0.1667   |
# | misc/timestep      | 18500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 114      |
# | reward/reward_max  | 129      |
# | reward/reward_min  | 93       |
# | reward/reward_std  | 13.379   |
# | loss/bellman_error | 1.0679   |
# | misc/q             | 30.942   |
# | misc/q_est         | 31.962   |
# | misc/epsilon       | 0.1658   |
# | misc/timestep      | 19000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 115.5    |
# | reward/reward_max  | 138      |
# | reward/reward_min  | 101      |
# | reward/reward_std  | 15.24    |
# | loss/bellman_error | 1.1463   |
# | misc/q             | 31.653   |
# | misc/q_est         | 32.75    |
# | misc/epsilon       | 0.1649   |
# | misc/timestep      | 19500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 120.2    |
# | reward/reward_max  | 133      |
# | reward/reward_min  | 98       |
# | reward/reward_std  | 12.544   |
# | loss/bellman_error | 1.1523   |
# | misc/q             | 32.394   |
# | misc/q_est         | 33.497   |
# | misc/epsilon       | 0.164    |
# | misc/timestep      | 20000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 130.67   |
# | reward/reward_max  | 148      |
# | reward/reward_min  | 115      |
# | reward/reward_std  | 13.524   |
# | loss/bellman_error | 1.1858   |
# | misc/q             | 33.116   |
# | misc/q_est         | 34.253   |
# | misc/epsilon       | 0.1631   |
# | misc/timestep      | 20500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 131.5    |
# | reward/reward_max  | 162      |
# | reward/reward_min  | 112      |
# | reward/reward_std  | 19.358   |
# | loss/bellman_error | 1.2374   |
# | misc/q             | 33.834   |
# | misc/q_est         | 35.022   |
# | misc/epsilon       | 0.1622   |
# | misc/timestep      | 21000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 135.75   |
# | reward/reward_max  | 157      |
# | reward/reward_min  | 125      |
# | reward/reward_std  | 12.716   |
# | loss/bellman_error | 1.1874   |
# | misc/q             | 34.605   |
# | misc/q_est         | 35.743   |
# | misc/epsilon       | 0.1613   |
# | misc/timestep      | 21500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 123      |
# | reward/reward_max  | 135      |
# | reward/reward_min  | 118      |
# | reward/reward_std  | 7.0356   |
# | loss/bellman_error | 1.1852   |
# | misc/q             | 35.335   |
# | misc/q_est         | 36.472   |
# | misc/epsilon       | 0.1604   |
# | misc/timestep      | 22000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 134.75   |
# | reward/reward_max  | 153      |
# | reward/reward_min  | 112      |
# | reward/reward_std  | 15.27    |
# | loss/bellman_error | 1.2555   |
# | misc/q             | 36.008   |
# | misc/q_est         | 37.213   |
# | misc/epsilon       | 0.1595   |
# | misc/timestep      | 22500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 134.67   |
# | reward/reward_max  | 162      |
# | reward/reward_min  | 121      |
# | reward/reward_std  | 19.328   |
# | loss/bellman_error | 1.1336   |
# | misc/q             | 36.904   |
# | misc/q_est         | 37.988   |
# | misc/epsilon       | 0.1586   |
# | misc/timestep      | 23000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 138      |
# | reward/reward_max  | 149      |
# | reward/reward_min  | 133      |
# | reward/reward_std  | 6.442    |
# | loss/bellman_error | 1.2826   |
# | misc/q             | 37.469   |
# | misc/q_est         | 38.7     |
# | misc/epsilon       | 0.1577   |
# | misc/timestep      | 23500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 167.33   |
# | reward/reward_max  | 192      |
# | reward/reward_min  | 147      |
# | reward/reward_std  | 18.625   |
# | loss/bellman_error | 1.2545   |
# | misc/q             | 38.29    |
# | misc/q_est         | 39.494   |
# | misc/epsilon       | 0.1568   |
# | misc/timestep      | 24000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 190.5    |
# | reward/reward_max  | 202      |
# | reward/reward_min  | 179      |
# | reward/reward_std  | 11.5     |
# | loss/bellman_error | 1.2204   |
# | misc/q             | 39.142   |
# | misc/q_est         | 40.313   |
# | misc/epsilon       | 0.1559   |
# | misc/timestep      | 24500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 205.33   |
# | reward/reward_max  | 229      |
# | reward/reward_min  | 186      |
# | reward/reward_std  | 17.82    |
# | loss/bellman_error | 1.2127   |
# | misc/q             | 39.81    |
# | misc/q_est         | 40.973   |
# | misc/epsilon       | 0.155    |
# | misc/timestep      | 25000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 199.5    |
# | reward/reward_max  | 214      |
# | reward/reward_min  | 185      |
# | reward/reward_std  | 14.5     |
# | loss/bellman_error | 1.213    |
# | misc/q             | 40.551   |
# | misc/q_est         | 41.715   |
# | misc/epsilon       | 0.1541   |
# | misc/timestep      | 25500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 214      |
# | reward/reward_max  | 230      |
# | reward/reward_min  | 198      |
# | reward/reward_std  | 16       |
# | loss/bellman_error | 1.2467   |
# | misc/q             | 41.241   |
# | misc/q_est         | 42.435   |
# | misc/epsilon       | 0.1532   |
# | misc/timestep      | 26000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 222.33   |
# | reward/reward_max  | 280      |
# | reward/reward_min  | 180      |
# | reward/reward_std  | 42.24    |
# | loss/bellman_error | 1.2119   |
# | misc/q             | 42.011   |
# | misc/q_est         | 43.172   |
# | misc/epsilon       | 0.1523   |
# | misc/timestep      | 26500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 189.33   |
# | reward/reward_max  | 265      |
# | reward/reward_min  | 143      |
# | reward/reward_std  | 53.953   |
# | loss/bellman_error | 1.2802   |
# | misc/q             | 42.669   |
# | misc/q_est         | 43.897   |
# | misc/epsilon       | 0.1514   |
# | misc/timestep      | 27000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 146.33   |
# | reward/reward_max  | 181      |
# | reward/reward_min  | 123      |
# | reward/reward_std  | 24.998   |
# | loss/bellman_error | 1.3093   |
# | misc/q             | 43.35    |
# | misc/q_est         | 44.608   |
# | misc/epsilon       | 0.1505   |
# | misc/timestep      | 27500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 124.5    |
# | reward/reward_max  | 129      |
# | reward/reward_min  | 122      |
# | reward/reward_std  | 2.6926   |
# | loss/bellman_error | 1.3281   |
# | misc/q             | 44.134   |
# | misc/q_est         | 45.409   |
# | misc/epsilon       | 0.1496   |
# | misc/timestep      | 28000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 123.25   |
# | reward/reward_max  | 149      |
# | reward/reward_min  | 97       |
# | reward/reward_std  | 20.401   |
# | loss/bellman_error | 1.3361   |
# | misc/q             | 44.894   |
# | misc/q_est         | 46.177   |
# | misc/epsilon       | 0.1487   |
# | misc/timestep      | 28500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 187      |
# | reward/reward_max  | 248      |
# | reward/reward_min  | 141      |
# | reward/reward_std  | 44.952   |
# | loss/bellman_error | 1.2487   |
# | misc/q             | 45.823   |
# | misc/q_est         | 47.021   |
# | misc/epsilon       | 0.1478   |
# | misc/timestep      | 29000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 141.67   |
# | reward/reward_max  | 175      |
# | reward/reward_min  | 112      |
# | reward/reward_std  | 25.85    |
# | loss/bellman_error | 1.1694   |
# | misc/q             | 46.635   |
# | misc/q_est         | 47.753   |
# | misc/epsilon       | 0.1469   |
# | misc/timestep      | 29500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 139      |
# | reward/reward_max  | 204      |
# | reward/reward_min  | 48       |
# | reward/reward_std  | 58.953   |
# | loss/bellman_error | 1.2644   |
# | misc/q             | 47.268   |
# | misc/q_est         | 48.481   |
# | misc/epsilon       | 0.146    |
# | misc/timestep      | 30000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 117.25   |
# | reward/reward_max  | 157      |
# | reward/reward_min  | 88       |
# | reward/reward_std  | 25.44    |
# | loss/bellman_error | 1.2013   |
# | misc/q             | 48.063   |
# | misc/q_est         | 49.214   |
# | misc/epsilon       | 0.1451   |
# | misc/timestep      | 30500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 138.75   |
# | reward/reward_max  | 196      |
# | reward/reward_min  | 97       |
# | reward/reward_std  | 36.1     |
# | loss/bellman_error | 1.2204   |
# | misc/q             | 48.836   |
# | misc/q_est         | 50.007   |
# | misc/epsilon       | 0.1442   |
# | misc/timestep      | 31000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 110      |
# | reward/reward_max  | 137      |
# | reward/reward_min  | 90       |
# | reward/reward_std  | 20.603   |
# | loss/bellman_error | 1.2672   |
# | misc/q             | 49.44    |
# | misc/q_est         | 50.656   |
# | misc/epsilon       | 0.1433   |
# | misc/timestep      | 31500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 117      |
# | reward/reward_max  | 126      |
# | reward/reward_min  | 103      |
# | reward/reward_std  | 8.5147   |
# | loss/bellman_error | 1.3395   |
# | misc/q             | 50.005   |
# | misc/q_est         | 51.294   |
# | misc/epsilon       | 0.1424   |
# | misc/timestep      | 32000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 171.33   |
# | reward/reward_max  | 206      |
# | reward/reward_min  | 121      |
# | reward/reward_std  | 36.426   |
# | loss/bellman_error | 1.2862   |
# | misc/q             | 50.675   |
# | misc/q_est         | 51.911   |
# | misc/epsilon       | 0.1415   |
# | misc/timestep      | 32500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 104.6    |
# | reward/reward_max  | 121      |
# | reward/reward_min  | 99       |
# | reward/reward_std  | 8.5229   |
# | loss/bellman_error | 1.2893   |
# | misc/q             | 51.372   |
# | misc/q_est         | 52.61    |
# | misc/epsilon       | 0.1406   |
# | misc/timestep      | 33000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 102.4    |
# | reward/reward_max  | 125      |
# | reward/reward_min  | 81       |
# | reward/reward_std  | 14.444   |
# | loss/bellman_error | 1.269    |
# | misc/q             | 52.068   |
# | misc/q_est         | 53.288   |
# | misc/epsilon       | 0.1397   |
# | misc/timestep      | 33500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 130.25   |
# | reward/reward_max  | 217      |
# | reward/reward_min  | 97       |
# | reward/reward_std  | 50.167   |
# | loss/bellman_error | 1.2713   |
# | misc/q             | 52.577   |
# | misc/q_est         | 53.799   |
# | misc/epsilon       | 0.1388   |
# | misc/timestep      | 34000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 106.6    |
# | reward/reward_max  | 151      |
# | reward/reward_min  | 83       |
# | reward/reward_std  | 23.415   |
# | loss/bellman_error | 1.2434   |
# | misc/q             | 53.332   |
# | misc/q_est         | 54.527   |
# | misc/epsilon       | 0.1379   |
# | misc/timestep      | 34500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 105      |
# | reward/reward_max  | 125      |
# | reward/reward_min  | 93       |
# | reward/reward_std  | 12       |
# | loss/bellman_error | 1.2259   |
# | misc/q             | 53.946   |
# | misc/q_est         | 55.125   |
# | misc/epsilon       | 0.137    |
# | misc/timestep      | 35000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 112.2    |
# | reward/reward_max  | 147      |
# | reward/reward_min  | 88       |
# | reward/reward_std  | 19.177   |
# | loss/bellman_error | 1.4162   |
# | misc/q             | 54.324   |
# | misc/q_est         | 55.688   |
# | misc/epsilon       | 0.1361   |
# | misc/timestep      | 35500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 117      |
# | reward/reward_max  | 146      |
# | reward/reward_min  | 100      |
# | reward/reward_std  | 18.235   |
# | loss/bellman_error | 1.2892   |
# | misc/q             | 55.031   |
# | misc/q_est         | 56.273   |
# | misc/epsilon       | 0.1352   |
# | misc/timestep      | 36000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 111      |
# | reward/reward_max  | 131      |
# | reward/reward_min  | 81       |
# | reward/reward_std  | 20.543   |
# | loss/bellman_error | 1.288    |
# | misc/q             | 55.66    |
# | misc/q_est         | 56.902   |
# | misc/epsilon       | 0.1343   |
# | misc/timestep      | 36500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 106      |
# | reward/reward_max  | 131      |
# | reward/reward_min  | 88       |
# | reward/reward_std  | 14.697   |
# | loss/bellman_error | 1.3817   |
# | misc/q             | 56.17    |
# | misc/q_est         | 57.505   |
# | misc/epsilon       | 0.1334   |
# | misc/timestep      | 37000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 130      |
# | reward/reward_max  | 189      |
# | reward/reward_min  | 79       |
# | reward/reward_std  | 44.822   |
# | loss/bellman_error | 1.3895   |
# | misc/q             | 56.679   |
# | misc/q_est         | 58.022   |
# | misc/epsilon       | 0.1325   |
# | misc/timestep      | 37500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 130.25   |
# | reward/reward_max  | 217      |
# | reward/reward_min  | 96       |
# | reward/reward_std  | 50.211   |
# | loss/bellman_error | 1.1197   |
# | misc/q             | 57.544   |
# | misc/q_est         | 58.622   |
# | misc/epsilon       | 0.1316   |
# | misc/timestep      | 38000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 89.8     |
# | reward/reward_max  | 111      |
# | reward/reward_min  | 73       |
# | reward/reward_std  | 13.585   |
# | loss/bellman_error | 1.404    |
# | misc/q             | 57.821   |
# | misc/q_est         | 59.181   |
# | misc/epsilon       | 0.1307   |
# | misc/timestep      | 38500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 94.167   |
# | reward/reward_max  | 127      |
# | reward/reward_min  | 80       |
# | reward/reward_std  | 16.046   |
# | loss/bellman_error | 1.2871   |
# | misc/q             | 58.551   |
# | misc/q_est         | 59.795   |
# | misc/epsilon       | 0.1298   |
# | misc/timestep      | 39000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 86.5     |
# | reward/reward_max  | 104      |
# | reward/reward_min  | 70       |
# | reward/reward_std  | 10.436   |
# | loss/bellman_error | 1.3692   |
# | misc/q             | 59.055   |
# | misc/q_est         | 60.38    |
# | misc/epsilon       | 0.1289   |
# | misc/timestep      | 39500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 81.667   |
# | reward/reward_max  | 108      |
# | reward/reward_min  | 37       |
# | reward/reward_std  | 21.554   |
# | loss/bellman_error | 1.4962   |
# | misc/q             | 59.456   |
# | misc/q_est         | 60.906   |
# | misc/epsilon       | 0.128    |
# | misc/timestep      | 40000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 83.6     |
# | reward/reward_max  | 99       |
# | reward/reward_min  | 71       |
# | reward/reward_std  | 9.0686   |
# | loss/bellman_error | 1.4111   |
# | misc/q             | 59.995   |
# | misc/q_est         | 61.36    |
# | misc/epsilon       | 0.1271   |
# | misc/timestep      | 40500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 90.5     |
# | reward/reward_max  | 111      |
# | reward/reward_min  | 79       |
# | reward/reward_std  | 10.689   |
# | loss/bellman_error | 1.2844   |
# | misc/q             | 60.753   |
# | misc/q_est         | 61.998   |
# | misc/epsilon       | 0.1262   |
# | misc/timestep      | 41000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 72.571   |
# | reward/reward_max  | 85       |
# | reward/reward_min  | 63       |
# | reward/reward_std  | 9.4242   |
# | loss/bellman_error | 1.4038   |
# | misc/q             | 61.141   |
# | misc/q_est         | 62.503   |
# | misc/epsilon       | 0.1253   |
# | misc/timestep      | 41500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 76       |
# | reward/reward_max  | 88       |
# | reward/reward_min  | 67       |
# | reward/reward_std  | 8.0623   |
# | loss/bellman_error | 1.2695   |
# | misc/q             | 61.816   |
# | misc/q_est         | 63.045   |
# | misc/epsilon       | 0.1244   |
# | misc/timestep      | 42000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 78.714   |
# | reward/reward_max  | 95       |
# | reward/reward_min  | 67       |
# | reward/reward_std  | 9.1138   |
# | loss/bellman_error | 1.3651   |
# | misc/q             | 62.188   |
# | misc/q_est         | 63.513   |
# | misc/epsilon       | 0.1235   |
# | misc/timestep      | 42500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 72.857   |
# | reward/reward_max  | 87       |
# | reward/reward_min  | 63       |
# | reward/reward_std  | 7.2787   |
# | loss/bellman_error | 1.3238   |
# | misc/q             | 62.796   |
# | misc/q_est         | 64.081   |
# | misc/epsilon       | 0.1226   |
# | misc/timestep      | 43000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 73.714   |
# | reward/reward_max  | 90       |
# | reward/reward_min  | 67       |
# | reward/reward_std  | 7.3623   |
# | loss/bellman_error | 1.4785   |
# | misc/q             | 63.12    |
# | misc/q_est         | 64.555   |
# | misc/epsilon       | 0.1217   |
# | misc/timestep      | 43500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 75.833   |
# | reward/reward_max  | 87       |
# | reward/reward_min  | 66       |
# | reward/reward_std  | 7.1044   |
# | loss/bellman_error | 1.2668   |
# | misc/q             | 63.819   |
# | misc/q_est         | 65.045   |
# | misc/epsilon       | 0.1208   |
# | misc/timestep      | 44000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 66.875   |
# | reward/reward_max  | 88       |
# | reward/reward_min  | 12       |
# | reward/reward_std  | 23.577   |
# | loss/bellman_error | 1.3201   |
# | misc/q             | 64.218   |
# | misc/q_est         | 65.499   |
# | misc/epsilon       | 0.1199   |
# | misc/timestep      | 44500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 62.625   |
# | reward/reward_max  | 83       |
# | reward/reward_min  | 26       |
# | reward/reward_std  | 18.131   |
# | loss/bellman_error | 1.3742   |
# | misc/q             | 64.678   |
# | misc/q_est         | 66.01    |
# | misc/epsilon       | 0.119    |
# | misc/timestep      | 45000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 80.167   |
# | reward/reward_max  | 96       |
# | reward/reward_min  | 69       |
# | reward/reward_std  | 10.024   |
# | loss/bellman_error | 1.3155   |
# | misc/q             | 65.23    |
# | misc/q_est         | 66.507   |
# | misc/epsilon       | 0.1181   |
# | misc/timestep      | 45500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 71.429   |
# | reward/reward_max  | 85       |
# | reward/reward_min  | 63       |
# | reward/reward_std  | 7.5377   |
# | loss/bellman_error | 1.4131   |
# | misc/q             | 65.591   |
# | misc/q_est         | 66.961   |
# | misc/epsilon       | 0.1172   |
# | misc/timestep      | 46000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 72.429   |
# | reward/reward_max  | 84       |
# | reward/reward_min  | 61       |
# | reward/reward_std  | 6.8839   |
# | loss/bellman_error | 1.4336   |
# | misc/q             | 66.056   |
# | misc/q_est         | 67.444   |
# | misc/epsilon       | 0.1163   |
# | misc/timestep      | 46500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 75.571   |
# | reward/reward_max  | 86       |
# | reward/reward_min  | 69       |
# | reward/reward_std  | 5.9727   |
# | loss/bellman_error | 1.4126   |
# | misc/q             | 66.641   |
# | misc/q_est         | 68.01    |
# | misc/epsilon       | 0.1154   |
# | misc/timestep      | 47000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 76       |
# | reward/reward_max  | 82       |
# | reward/reward_min  | 63       |
# | reward/reward_std  | 7.1414   |
# | loss/bellman_error | 1.5097   |
# | misc/q             | 66.895   |
# | misc/q_est         | 68.36    |
# | misc/epsilon       | 0.1145   |
# | misc/timestep      | 47500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 73.429   |
# | reward/reward_max  | 76       |
# | reward/reward_min  | 68       |
# | reward/reward_std  | 2.9692   |
# | loss/bellman_error | 1.4275   |
# | misc/q             | 67.426   |
# | misc/q_est         | 68.81    |
# | misc/epsilon       | 0.1136   |
# | misc/timestep      | 48000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 75.429   |
# | reward/reward_max  | 81       |
# | reward/reward_min  | 69       |
# | reward/reward_std  | 3.959    |
# | loss/bellman_error | 1.3493   |
# | misc/q             | 68.108   |
# | misc/q_est         | 69.413   |
# | misc/epsilon       | 0.1127   |
# | misc/timestep      | 48500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 64.286   |
# | reward/reward_max  | 81       |
# | reward/reward_min  | 25       |
# | reward/reward_std  | 18.359   |
# | loss/bellman_error | 1.257    |
# | misc/q             | 68.548   |
# | misc/q_est         | 69.763   |
# | misc/epsilon       | 0.1118   |
# | misc/timestep      | 49000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 70.857   |
# | reward/reward_max  | 78       |
# | reward/reward_min  | 67       |
# | reward/reward_std  | 3.9071   |
# | loss/bellman_error | 1.3585   |
# | misc/q             | 68.924   |
# | misc/q_est         | 70.238   |
# | misc/epsilon       | 0.1109   |
# | misc/timestep      | 49500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 63.5     |
# | reward/reward_max  | 76       |
# | reward/reward_min  | 12       |
# | reward/reward_std  | 19.679   |
# | loss/bellman_error | 1.3953   |
# | misc/q             | 69.279   |
# | misc/q_est         | 70.63    |
# | misc/epsilon       | 0.11     |
# | misc/timestep      | 50000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 71.286   |
# | reward/reward_max  | 77       |
# | reward/reward_min  | 66       |
# | reward/reward_std  | 3.8809   |
# | loss/bellman_error | 1.367    |
# | misc/q             | 69.632   |
# | misc/q_est         | 70.955   |
# | misc/epsilon       | 0.1091   |
# | misc/timestep      | 50500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 67.429   |
# | reward/reward_max  | 74       |
# | reward/reward_min  | 60       |
# | reward/reward_std  | 4.6247   |
# | loss/bellman_error | 1.4057   |
# | misc/q             | 69.988   |
# | misc/q_est         | 71.347   |
# | misc/epsilon       | 0.1082   |
# | misc/timestep      | 51000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 72       |
# | reward/reward_max  | 83       |
# | reward/reward_min  | 67       |
# | reward/reward_std  | 4.6904   |
# | loss/bellman_error | 1.3605   |
# | misc/q             | 70.495   |
# | misc/q_est         | 71.811   |
# | misc/epsilon       | 0.1073   |
# | misc/timestep      | 51500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 71.714   |
# | reward/reward_max  | 85       |
# | reward/reward_min  | 65       |
# | reward/reward_std  | 6.4079   |
# | loss/bellman_error | 1.3518   |
# | misc/q             | 70.957   |
# | misc/q_est         | 72.266   |
# | misc/epsilon       | 0.1064   |
# | misc/timestep      | 52000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 62.5     |
# | reward/reward_max  | 72       |
# | reward/reward_min  | 14       |
# | reward/reward_std  | 18.392   |
# | loss/bellman_error | 1.2447   |
# | misc/q             | 71.55    |
# | misc/q_est         | 72.756   |
# | misc/epsilon       | 0.1055   |
# | misc/timestep      | 52500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 70.286   |
# | reward/reward_max  | 77       |
# | reward/reward_min  | 65       |
# | reward/reward_std  | 3.6533   |
# | loss/bellman_error | 1.1891   |
# | misc/q             | 72.038   |
# | misc/q_est         | 73.19    |
# | misc/epsilon       | 0.1046   |
# | misc/timestep      | 53000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 72.167   |
# | reward/reward_max  | 76       |
# | reward/reward_min  | 69       |
# | reward/reward_std  | 2.5441   |
# | loss/bellman_error | 1.247    |
# | misc/q             | 72.337   |
# | misc/q_est         | 73.546   |
# | misc/epsilon       | 0.1037   |
# | misc/timestep      | 53500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 71.875   |
# | reward/reward_max  | 88       |
# | reward/reward_min  | 61       |
# | reward/reward_std  | 7.753    |
# | loss/bellman_error | 1.2447   |
# | misc/q             | 72.711   |
# | misc/q_est         | 73.916   |
# | misc/epsilon       | 0.1028   |
# | misc/timestep      | 54000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 74.667   |
# | reward/reward_max  | 82       |
# | reward/reward_min  | 67       |
# | reward/reward_std  | 5.2493   |
# | loss/bellman_error | 1.3706   |
# | misc/q             | 72.955   |
# | misc/q_est         | 74.287   |
# | misc/epsilon       | 0.1019   |
# | misc/timestep      | 54500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 65.875   |
# | reward/reward_max  | 71       |
# | reward/reward_min  | 62       |
# | reward/reward_std  | 3.0593   |
# | loss/bellman_error | 1.2016   |
# | misc/q             | 73.545   |
# | misc/q_est         | 74.706   |
# | misc/epsilon       | 0.101    |
# | misc/timestep      | 55000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 67.143   |
# | reward/reward_max  | 72       |
# | reward/reward_min  | 62       |
# | reward/reward_std  | 3.3135   |
# | loss/bellman_error | 1.3236   |
# | misc/q             | 73.757   |
# | misc/q_est         | 75.039   |
# | misc/epsilon       | 0.1001   |
# | misc/timestep      | 55500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 70.857   |
# | reward/reward_max  | 79       |
# | reward/reward_min  | 65       |
# | reward/reward_std  | 3.9795   |
# | loss/bellman_error | 1.2573   |
# | misc/q             | 74.156   |
# | misc/q_est         | 75.37    |
# | misc/epsilon       | 0.0992   |
# | misc/timestep      | 56000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 71.286   |
# | reward/reward_max  | 84       |
# | reward/reward_min  | 59       |
# | reward/reward_std  | 6.9429   |
# | loss/bellman_error | 1.1871   |
# | misc/q             | 74.746   |
# | misc/q_est         | 75.894   |
# | misc/epsilon       | 0.0983   |
# | misc/timestep      | 56500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 68.625   |
# | reward/reward_max  | 75       |
# | reward/reward_min  | 63       |
# | reward/reward_std  | 3.4255   |
# | loss/bellman_error | 1.2116   |
# | misc/q             | 75.071   |
# | misc/q_est         | 76.244   |
# | misc/epsilon       | 0.0974   |
# | misc/timestep      | 57000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 69.143   |
# | reward/reward_max  | 76       |
# | reward/reward_min  | 58       |
# | reward/reward_std  | 6.1279   |
# | loss/bellman_error | 1.2117   |
# | misc/q             | 75.455   |
# | misc/q_est         | 76.628   |
# | misc/epsilon       | 0.0965   |
# | misc/timestep      | 57500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 71       |
# | reward/reward_max  | 74       |
# | reward/reward_min  | 67       |
# | reward/reward_std  | 2.9761   |
# | loss/bellman_error | 1.1788   |
# | misc/q             | 75.707   |
# | misc/q_est         | 76.846   |
# | misc/epsilon       | 0.0956   |
# | misc/timestep      | 58000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 72.143   |
# | reward/reward_max  | 76       |
# | reward/reward_min  | 65       |
# | reward/reward_std  | 3.5225   |
# | loss/bellman_error | 1.17     |
# | misc/q             | 75.996   |
# | misc/q_est         | 77.125   |
# | misc/epsilon       | 0.0947   |
# | misc/timestep      | 58500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 72.857   |
# | reward/reward_max  | 79       |
# | reward/reward_min  | 68       |
# | reward/reward_std  | 4.4217   |
# | loss/bellman_error | 1.0583   |
# | misc/q             | 76.532   |
# | misc/q_est         | 77.554   |
# | misc/epsilon       | 0.0938   |
# | misc/timestep      | 59000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 76.333   |
# | reward/reward_max  | 85       |
# | reward/reward_min  | 68       |
# | reward/reward_std  | 6.3683   |
# | loss/bellman_error | 1.0665   |
# | misc/q             | 76.703   |
# | misc/q_est         | 77.732   |
# | misc/epsilon       | 0.0929   |
# | misc/timestep      | 59500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 75.714   |
# | reward/reward_max  | 80       |
# | reward/reward_min  | 70       |
# | reward/reward_std  | 3.614    |
# | loss/bellman_error | 1.1006   |
# | misc/q             | 76.964   |
# | misc/q_est         | 78.024   |
# | misc/epsilon       | 0.092    |
# | misc/timestep      | 60000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 72.286   |
# | reward/reward_max  | 77       |
# | reward/reward_min  | 59       |
# | reward/reward_std  | 5.8239   |
# | loss/bellman_error | 1.0318   |
# | misc/q             | 77.074   |
# | misc/q_est         | 78.067   |
# | misc/epsilon       | 0.0911   |
# | misc/timestep      | 60500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 76.5     |
# | reward/reward_max  | 82       |
# | reward/reward_min  | 73       |
# | reward/reward_std  | 3.0957   |
# | loss/bellman_error | 0.86932  |
# | misc/q             | 77.558   |
# | misc/q_est         | 78.394   |
# | misc/epsilon       | 0.0902   |
# | misc/timestep      | 61000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 77.286   |
# | reward/reward_max  | 85       |
# | reward/reward_min  | 72       |
# | reward/reward_std  | 4.1305   |
# | loss/bellman_error | 0.98645  |
# | misc/q             | 77.749   |
# | misc/q_est         | 78.701   |
# | misc/epsilon       | 0.0893   |
# | misc/timestep      | 61500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 77       |
# | reward/reward_max  | 81       |
# | reward/reward_min  | 70       |
# | reward/reward_std  | 3.559    |
# | loss/bellman_error | 0.86244  |
# | misc/q             | 78.21    |
# | misc/q_est         | 79.041   |
# | misc/epsilon       | 0.0884   |
# | misc/timestep      | 62000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 77.857   |
# | reward/reward_max  | 85       |
# | reward/reward_min  | 68       |
# | reward/reward_std  | 5.1666   |
# | loss/bellman_error | 0.80235  |
# | misc/q             | 78.467   |
# | misc/q_est         | 79.24    |
# | misc/epsilon       | 0.0875   |
# | misc/timestep      | 62500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 83.5     |
# | reward/reward_max  | 95       |
# | reward/reward_min  | 76       |
# | reward/reward_std  | 6.3443   |
# | loss/bellman_error | 0.71888  |
# | misc/q             | 78.813   |
# | misc/q_est         | 79.505   |
# | misc/epsilon       | 0.0866   |
# | misc/timestep      | 63000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 84.667   |
# | reward/reward_max  | 91       |
# | reward/reward_min  | 76       |
# | reward/reward_std  | 4.9889   |
# | loss/bellman_error | 0.78325  |
# | misc/q             | 78.842   |
# | misc/q_est         | 79.599   |
# | misc/epsilon       | 0.0857   |
# | misc/timestep      | 63500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 87       |
# | reward/reward_max  | 99       |
# | reward/reward_min  | 79       |
# | reward/reward_std  | 7.2664   |
# | loss/bellman_error | 0.70258  |
# | misc/q             | 79.055   |
# | misc/q_est         | 79.733   |
# | misc/epsilon       | 0.0848   |
# | misc/timestep      | 64000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 68.25    |
# | reward/reward_max  | 83       |
# | reward/reward_min  | 12       |
# | reward/reward_std  | 21.58    |
# | loss/bellman_error | 0.90074  |
# | misc/q             | 78.994   |
# | misc/q_est         | 79.871   |
# | misc/epsilon       | 0.0839   |
# | misc/timestep      | 64500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 82.667   |
# | reward/reward_max  | 91       |
# | reward/reward_min  | 79       |
# | reward/reward_std  | 4.4222   |
# ...
# | reward/reward_min  | 179      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.61568  |
# | misc/q             | 80.361   |
# | misc/q_est         | 80.963   |
# | misc/epsilon       | 0.0578   |
# | misc/timestep      | 79000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.65823  |
# | misc/q             | 80.395   |
# | misc/q_est         | 81.039   |
# | misc/epsilon       | 0.0569   |
# | misc/timestep      | 79500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 360      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 220      |
# | reward/reward_std  | 140      |
# | loss/bellman_error | 0.65999  |
# | misc/q             | 80.225   |
# | misc/q_est         | 80.871   |
# | misc/epsilon       | 0.056    |
# | misc/timestep      | 80000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.5522   |
# | misc/q             | 80.304   |
# | misc/q_est         | 80.844   |
# | misc/epsilon       | 0.0551   |
# | misc/timestep      | 80500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 490      |
# | reward/reward_max  | 490      |
# | reward/reward_min  | 490      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.51622  |
# | misc/q             | 80.2     |
# | misc/q_est         | 80.704   |
# | misc/epsilon       | 0.0542   |
# | misc/timestep      | 81000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 313      |
# | reward/reward_max  | 351      |
# | reward/reward_min  | 275      |
# | reward/reward_std  | 38       |
# | loss/bellman_error | 0.58552  |
# | misc/q             | 80.075   |
# | misc/q_est         | 80.648   |
# | misc/epsilon       | 0.0533   |
# | misc/timestep      | 81500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 199      |
# | reward/reward_max  | 220      |
# | reward/reward_min  | 178      |
# | reward/reward_std  | 21       |
# | loss/bellman_error | 0.54606  |
# | misc/q             | 79.871   |
# | misc/q_est         | 80.405   |
# | misc/epsilon       | 0.0524   |
# | misc/timestep      | 82000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.62778  |
# | misc/q             | 79.607   |
# | misc/q_est         | 80.221   |
# | misc/epsilon       | 0.0515   |
# | misc/timestep      | 82500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.58362  |
# | misc/q             | 79.757   |
# | misc/q_est         | 80.327   |
# | misc/epsilon       | 0.0506   |
# | misc/timestep      | 83000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.54238  |
# | misc/q             | 79.765   |
# | misc/q_est         | 80.296   |
# | misc/epsilon       | 0.0497   |
# | misc/timestep      | 83500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.51572  |
# | misc/q             | 79.697   |
# | misc/q_est         | 80.2     |
# | misc/epsilon       | 0.0488   |
# | misc/timestep      | 84000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.55543  |
# | misc/q             | 79.575   |
# | misc/q_est         | 80.118   |
# | misc/epsilon       | 0.0479   |
# | misc/timestep      | 84500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.49624  |
# | misc/q             | 79.354   |
# | misc/q_est         | 79.838   |
# | misc/epsilon       | 0.047    |
# | misc/timestep      | 85000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.51836  |
# | misc/q             | 79.407   |
# | misc/q_est         | 79.913   |
# | misc/epsilon       | 0.0461   |
# | misc/timestep      | 85500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.47833  |
# | misc/q             | 79.69    |
# | misc/q_est         | 80.157   |
# | misc/epsilon       | 0.0452   |
# | misc/timestep      | 86000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.47605  |
# | misc/q             | 79.385   |
# | misc/q_est         | 79.848   |
# | misc/epsilon       | 0.0443   |
# | misc/timestep      | 86500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.4497   |
# | misc/q             | 79.399   |
# | misc/q_est         | 79.837   |
# | misc/epsilon       | 0.0434   |
# | misc/timestep      | 87000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.4715   |
# | misc/q             | 79.52    |
# | misc/q_est         | 79.979   |
# | misc/epsilon       | 0.0425   |
# | misc/timestep      | 87500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.42922  |
# | misc/q             | 79.49    |
# | misc/q_est         | 79.908   |
# | misc/epsilon       | 0.0416   |
# | misc/timestep      | 88000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.48292  |
# | misc/q             | 79.527   |
# | misc/q_est         | 79.999   |
# | misc/epsilon       | 0.0407   |
# | misc/timestep      | 88500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.4594   |
# | misc/q             | 79.452   |
# | misc/q_est         | 79.899   |
# | misc/epsilon       | 0.0398   |
# | misc/timestep      | 89000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.43509  |
# | misc/q             | 79.403   |
# | misc/q_est         | 79.826   |
# | misc/epsilon       | 0.0389   |
# | misc/timestep      | 89500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.40924  |
# | misc/q             | 79.715   |
# | misc/q_est         | 80.113   |
# | misc/epsilon       | 0.038    |
# | misc/timestep      | 90000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.40794  |
# | misc/q             | 79.942   |
# | misc/q_est         | 80.338   |
# | misc/epsilon       | 0.0371   |
# | misc/timestep      | 90500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.42147  |
# | misc/q             | 79.829   |
# | misc/q_est         | 80.239   |
# | misc/epsilon       | 0.0362   |
# | misc/timestep      | 91000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.38534  |
# | misc/q             | 79.918   |
# | misc/q_est         | 80.291   |
# | misc/epsilon       | 0.0353   |
# | misc/timestep      | 91500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.39746  |
# | misc/q             | 80.017   |
# | misc/q_est         | 80.402   |
# | misc/epsilon       | 0.0344   |
# | misc/timestep      | 92000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.36373  |
# | misc/q             | 80.043   |
# | misc/q_est         | 80.395   |
# | misc/epsilon       | 0.0335   |
# | misc/timestep      | 92500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.35955  |
# | misc/q             | 80.434   |
# | misc/q_est         | 80.781   |
# | misc/epsilon       | 0.0326   |
# | misc/timestep      | 93000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.42075  |
# | misc/q             | 80.766   |
# | misc/q_est         | 81.173   |
# | misc/epsilon       | 0.0317   |
# | misc/timestep      | 93500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.35387  |
# | misc/q             | 80.723   |
# | misc/q_est         | 81.065   |
# | misc/epsilon       | 0.0308   |
# | misc/timestep      | 94000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.3741   |
# | misc/q             | 80.96    |
# | misc/q_est         | 81.321   |
# | misc/epsilon       | 0.0299   |
# | misc/timestep      | 94500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.34037  |
# | misc/q             | 80.984   |
# | misc/q_est         | 81.311   |
# | misc/epsilon       | 0.029    |
# | misc/timestep      | 95000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.33302  |
# | misc/q             | 81.216   |
# | misc/q_est         | 81.537   |
# | misc/epsilon       | 0.0281   |
# | misc/timestep      | 95500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.35616  |
# | misc/q             | 81.357   |
# | misc/q_est         | 81.7     |
# | misc/epsilon       | 0.0272   |
# | misc/timestep      | 96000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.28724  |
# | misc/q             | 81.412   |
# | misc/q_est         | 81.688   |
# | misc/epsilon       | 0.0263   |
# | misc/timestep      | 96500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.29858  |
# | misc/q             | 81.709   |
# | misc/q_est         | 81.996   |
# | misc/epsilon       | 0.0254   |
# | misc/timestep      | 97000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.32809  |
# | misc/q             | 81.905   |
# | misc/q_est         | 82.221   |
# | misc/epsilon       | 0.0245   |
# | misc/timestep      | 97500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.28177  |
# | misc/q             | 82.374   |
# | misc/q_est         | 82.643   |
# | misc/epsilon       | 0.0236   |
# | misc/timestep      | 98000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.26859  |
# | misc/q             | 82.546   |
# | misc/q_est         | 82.802   |
# | misc/epsilon       | 0.0227   |
# | misc/timestep      | 98500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.25995  |
# | misc/q             | 83.043   |
# | misc/q_est         | 83.291   |
# | misc/epsilon       | 0.0218   |
# | misc/timestep      | 99000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.25379  |
# | misc/q             | 83.109   |
# | misc/q_est         | 83.35    |
# | misc/epsilon       | 0.0209   |
# | misc/timestep      | 99500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.24412  |
# | misc/q             | 83.304   |
# | misc/q_est         | 83.536   |
# | misc/epsilon       | 0.02     |
# | misc/timestep      | 1e+05    |
# ---------------------------------

# %% [markdown]
# Now, let's take a look at our learned policy in action:

# %%
env = make_env("CartPole-v1", monitor=True)
obs = env.reset()
while True:
    obs = torch.FloatTensor(obs).unsqueeze(0)
    act = agent.pick_action(obs, force_greedy=True)
    obs, rew, done, info = env.step(act)
    if done: break
env.close()

HTML(data=get_html_video_string(env.file_infix))
# Out:
# <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video></video>

# %%
def plot_progress(data, name=None):
    name = name or "Mean reward"
    plt.plot(data['misc/timestep'], data['reward/reward_mean'], label=name)
    lower = np.array(data['reward/reward_mean'] - data['reward/reward_std']).clip(-1e5, +1e5)
    upper = np.array(data['reward/reward_mean'] + data['reward/reward_std']).clip(-1e5, +1e5)
    examples = np.array(data['misc/timestep'])
    plt.fill_between(list(examples), list(lower), list(upper), color='blue', alpha=0.1)
    plt.legend(loc='best')
    plt.xlabel("Timestep")
    plt.ylabel("Reward")

# %% [markdown]
# The following cell plots a mean reward against training iterations. Note, that the agent may sometimes degrade its performance.

# %%
plt.figure(dpi=300)
df = pd.read_csv(str(log_root / "cartpole-v1" / "logs_dqn.csv"), sep=";")
plot_progress(df)

# %% [markdown]
# #LunarLander
# Okay, now that we're done with very simple CartPole environment, let's move to something more complicated.
#
# LunarLander is a simulation game where a player has to control the capsule and land it on the zone marked with flags. If an agent achieves more than 200 scores, the environment is said to be solved.
#
# First, you should install Box2D support in Gym:

# %%
# !pip install 'gym[box2d]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[box2d] in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.15.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.21.6)
# Requirement already satisfied: cloudpickle~=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.2.2)
# Requirement already satisfied: pyglet<=1.3.2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.3.2)
# Requirement already satisfied: box2d-py~=2.3.5 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (2.3.8)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.3.2,>=1.2.0->gym[box2d]) (0.16.0)

# %%
env = make_env("LunarLander-v2", monitor=True)
env.reset()
while True:
    action = env.action_space.sample()
    if env.step(action)[2]: break
env.close()

HTML(data=get_html_video_string(env.file_infix))
# Out:
# <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video></video>

# %%
env = make_env("LunarLander-v2", SEED)

value_network = get_network("mlp")(
    env.observation_space.shape[0],
    256,
    env.action_space.n)

agent = DQN(
    value_network,
    env.action_space,
    eps=.3,
    eps_decay=(.3 - .02) / 10**5 / 2,
    batch_size=64,
    learning_rate=1e-4,
    discount_factor=.99
)

# %%
agent = train(
    agent,
    env,
    log_dir=log_root / "lunarlander-v2",
    prefix="_dqn",
    buffer_size=10**5,
    n_steps=2*10**5,
    warmup_steps=10000,
    target_update_every=500,
    log_every=4000,
    save_every=1000
)
# Out:
# ---------------------------------
# | reward/reward_mean | -199.19  |
# | reward/reward_max  | 74.163   |
# | reward/reward_min  | -643.66  |
# | reward/reward_std  | 148.47   |
# | loss/bellman_error | 2.4594   |
# | misc/q             | -2.1121  |
# | misc/q_est         | -1.2386  |
# | misc/epsilon       | 0.2832   |
# | misc/timestep      | 12000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -154.11  |
# | reward/reward_max  | -36.001  |
# | reward/reward_min  | -268.94  |
# | reward/reward_std  | 64.346   |
# | loss/bellman_error | 2.1239   |
# | misc/q             | -1.631   |
# | misc/q_est         | -1.1148  |
# | misc/epsilon       | 0.2776   |
# | misc/timestep      | 16000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -168.41  |
# | reward/reward_max  | -30.215  |
# | reward/reward_min  | -310.44  |
# | reward/reward_std  | 89.408   |
# | loss/bellman_error | 1.9803   |
# | misc/q             | 0.3342   |
# | misc/q_est         | 0.80902  |
# | misc/epsilon       | 0.272    |
# | misc/timestep      | 20000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -76.89   |
# | reward/reward_max  | 22.216   |
# | reward/reward_min  | -124.19  |
# | reward/reward_std  | 48.473   |
# | loss/bellman_error | 1.8499   |
# | misc/q             | 2.7445   |
# | misc/q_est         | 3.1571   |
# | misc/epsilon       | 0.2664   |
# | misc/timestep      | 24000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -38.063  |
# | reward/reward_max  | 5.0639   |
# | reward/reward_min  | -99.032  |
# | reward/reward_std  | 39.152   |
# | loss/bellman_error | 1.8034   |
# | misc/q             | 5.7971   |
# | misc/q_est         | 6.0932   |
# | misc/epsilon       | 0.2608   |
# | misc/timestep      | 28000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -48.954  |
# | reward/reward_max  | 74.682   |
# | reward/reward_min  | -115.2   |
# | reward/reward_std  | 66.765   |
# | loss/bellman_error | 1.7052   |
# | misc/q             | 9.156    |
# | misc/q_est         | 9.4209   |
# | misc/epsilon       | 0.2552   |
# | misc/timestep      | 32000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 30.106   |
# | reward/reward_max  | 80.254   |
# | reward/reward_min  | -23.037  |
# | reward/reward_std  | 43.007   |
# | loss/bellman_error | 1.6637   |
# | misc/q             | 12.31    |
# | misc/q_est         | 12.556   |
# | misc/epsilon       | 0.2496   |
# | misc/timestep      | 36000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 68.902   |
# | reward/reward_max  | 211.29   |
# | reward/reward_min  | -96.557  |
# | reward/reward_std  | 109.53   |
# | loss/bellman_error | 1.6353   |
# | misc/q             | 14.895   |
# | misc/q_est         | 15.117   |
# | misc/epsilon       | 0.244    |
# | misc/timestep      | 40000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -15.27   |
# | reward/reward_max  | 112.89   |
# | reward/reward_min  | -108.18  |
# | reward/reward_std  | 73.307   |
# | loss/bellman_error | 1.6027   |
# | misc/q             | 17.112   |
# | misc/q_est         | 17.335   |
# | misc/epsilon       | 0.2384   |
# | misc/timestep      | 44000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 95.073   |
# | reward/reward_max  | 182.81   |
# | reward/reward_min  | -96.944  |
# | reward/reward_std  | 98.734   |
# | loss/bellman_error | 1.5824   |
# | misc/q             | 19.346   |
# | misc/q_est         | 19.593   |
# | misc/epsilon       | 0.2328   |
# | misc/timestep      | 48000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 2.3563   |
# | reward/reward_max  | 199.02   |
# | reward/reward_min  | -75.567  |
# | reward/reward_std  | 84.147   |
# | loss/bellman_error | 1.5734   |
# | misc/q             | 20.885   |
# | misc/q_est         | 21.14    |
# | misc/epsilon       | 0.2272   |
# | misc/timestep      | 52000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -23.797  |
# | reward/reward_max  | 128.15   |
# | reward/reward_min  | -77.909  |
# | reward/reward_std  | 62.124   |
# | loss/bellman_error | 1.5126   |
# | misc/q             | 22.319   |
# | misc/q_est         | 22.582   |
# | misc/epsilon       | 0.2216   |
# | misc/timestep      | 56000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -34.4    |
# | reward/reward_max  | 26.886   |
# | reward/reward_min  | -112.28  |
# | reward/reward_std  | 37.19    |
# | loss/bellman_error | 1.4594   |
# | misc/q             | 23.563   |
# | misc/q_est         | 23.826   |
# | misc/epsilon       | 0.216    |
# | misc/timestep      | 60000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -25.385  |
# | reward/reward_max  | 29.667   |
# | reward/reward_min  | -94.381  |
# | reward/reward_std  | 37.514   |
# | loss/bellman_error | 1.3988   |
# | misc/q             | 24.56    |
# | misc/q_est         | 24.803   |
# | misc/epsilon       | 0.2104   |
# | misc/timestep      | 64000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -45.623  |
# | reward/reward_max  | 19.382   |
# | reward/reward_min  | -99.083  |
# | reward/reward_std  | 36.506   |
# | loss/bellman_error | 1.3298   |
# | misc/q             | 25.145   |
# | misc/q_est         | 25.422   |
# | misc/epsilon       | 0.2048   |
# | misc/timestep      | 68000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -37.334  |
# | reward/reward_max  | 27.923   |
# | reward/reward_min  | -122.96  |
# | reward/reward_std  | 48.433   |
# | loss/bellman_error | 1.287    |
# | misc/q             | 25.392   |
# | misc/q_est         | 25.657   |
# | misc/epsilon       | 0.1992   |
# | misc/timestep      | 72000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 14.305   |
# | reward/reward_max  | 98.84    |
# | reward/reward_min  | -83.898  |
# | reward/reward_std  | 48.522   |
# | loss/bellman_error | 1.2661   |
# | misc/q             | 25.274   |
# | misc/q_est         | 25.557   |
# | misc/epsilon       | 0.1936   |
# | misc/timestep      | 76000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 184.72   |
# | reward/reward_max  | 236.61   |
# | reward/reward_min  | 98.743   |
# | reward/reward_std  | 47.869   |
# | loss/bellman_error | 1.2048   |
# | misc/q             | 25.092   |
# | misc/q_est         | 25.298   |
# | misc/epsilon       | 0.188    |
# | misc/timestep      | 80000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 39.035   |
# | reward/reward_max  | 251.77   |
# | reward/reward_min  | -116.38  |
# | reward/reward_std  | 111.18   |
# | loss/bellman_error | 1.1609   |
# | misc/q             | 24.754   |
# | misc/q_est         | 24.95    |
# | misc/epsilon       | 0.1824   |
# | misc/timestep      | 84000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 107.52   |
# | reward/reward_max  | 268.44   |
# | reward/reward_min  | -57.132  |
# | reward/reward_std  | 134.17   |
# | loss/bellman_error | 1.1463   |
# | misc/q             | 24.713   |
# | misc/q_est         | 24.929   |
# | misc/epsilon       | 0.1768   |
# | misc/timestep      | 88000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 137.22   |
# | reward/reward_max  | 259.21   |
# | reward/reward_min  | 2.6016   |
# | reward/reward_std  | 97.835   |
# | loss/bellman_error | 1.1606   |
# | misc/q             | 24.474   |
# | misc/q_est         | 24.633   |
# | misc/epsilon       | 0.1712   |
# | misc/timestep      | 92000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 82.416   |
# | reward/reward_max  | 266.02   |
# | reward/reward_min  | -21.541  |
# | reward/reward_std  | 106.07   |
# | loss/bellman_error | 1.19     |
# | misc/q             | 24.549   |
# | misc/q_est         | 24.724   |
# | misc/epsilon       | 0.1656   |
# | misc/timestep      | 96000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 26.929   |
# | reward/reward_max  | 242.84   |
# | reward/reward_min  | -73.03   |
# | reward/reward_std  | 97.105   |
# | loss/bellman_error | 1.1624   |
# | misc/q             | 24.952   |
# | misc/q_est         | 25.117   |
# | misc/epsilon       | 0.16     |
# | misc/timestep      | 1e+05    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 206.04   |
# | reward/reward_max  | 247.31   |
# | reward/reward_min  | 127.84   |
# | reward/reward_std  | 35.139   |
# | loss/bellman_error | 1.156    |
# | misc/q             | 24.674   |
# | misc/q_est         | 24.781   |
# | misc/epsilon       | 0.1544   |
# | misc/timestep      | 1.04e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 97.612   |
# | reward/reward_max  | 258      |
# | reward/reward_min  | -67.459  |
# | reward/reward_std  | 117.61   |
# | loss/bellman_error | 1.0331   |
# | misc/q             | 24.242   |
# | misc/q_est         | 24.365   |
# | misc/epsilon       | 0.1488   |
# | misc/timestep      | 1.08e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 138.22   |
# | reward/reward_max  | 238.1    |
# | reward/reward_min  | -7.5614  |
# | reward/reward_std  | 105.3    |
# | loss/bellman_error | 0.96134  |
# | misc/q             | 23.599   |
# | misc/q_est         | 23.655   |
# | misc/epsilon       | 0.1432   |
# | misc/timestep      | 1.12e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 54.413   |
# | reward/reward_max  | 219.11   |
# | reward/reward_min  | -65.288  |
# | reward/reward_std  | 97.753   |
# | loss/bellman_error | 0.90308  |
# | misc/q             | 23.307   |
# | misc/q_est         | 23.369   |
# | misc/epsilon       | 0.1376   |
# | misc/timestep      | 1.16e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 173.82   |
# | reward/reward_max  | 273.92   |
# | reward/reward_min  | 10.285   |
# | reward/reward_std  | 85.939   |
# | loss/bellman_error | 0.87882  |
# | misc/q             | 23.337   |
# | misc/q_est         | 23.389   |
# | misc/epsilon       | 0.132    |
# | misc/timestep      | 1.2e+05  |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 41.659   |
# | reward/reward_max  | 189.77   |
# | reward/reward_min  | -75.23   |
# | reward/reward_std  | 105.65   |
# | loss/bellman_error | 0.8526   |
# | misc/q             | 23.537   |
# | misc/q_est         | 23.582   |
# | misc/epsilon       | 0.1264   |
# | misc/timestep      | 1.24e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -24.836  |
# | reward/reward_max  | 244.22   |
# | reward/reward_min  | -101.05  |
# | reward/reward_std  | 111.76   |
# | loss/bellman_error | 0.87538  |
# | misc/q             | 23.926   |
# | misc/q_est         | 23.97    |
# | misc/epsilon       | 0.1208   |
# | misc/timestep      | 1.28e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 27.88    |
# | reward/reward_max  | 226.08   |
# | reward/reward_min  | -79.242  |
# | reward/reward_std  | 118.98   |
# | loss/bellman_error | 0.87974  |
# | misc/q             | 24.583   |
# | misc/q_est         | 24.634   |
# | misc/epsilon       | 0.1152   |
# | misc/timestep      | 1.32e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 106.36   |
# | reward/reward_max  | 242.78   |
# | reward/reward_min  | -103.96  |
# | reward/reward_std  | 137.89   |
# | loss/bellman_error | 0.90427  |
# | misc/q             | 25.224   |
# | misc/q_est         | 25.273   |
# | misc/epsilon       | 0.1096   |
# | misc/timestep      | 1.36e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 76.427   |
# | reward/reward_max  | 223.05   |
# | reward/reward_min  | -131.61  |
# | reward/reward_std  | 134.84   |
# | loss/bellman_error | 0.90713  |
# | misc/q             | 25.41    |
# | misc/q_est         | 25.476   |
# | misc/epsilon       | 0.104    |
# | misc/timestep      | 1.4e+05  |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 96.193   |
# | reward/reward_max  | 238.99   |
# | reward/reward_min  | -50.831  |
# | reward/reward_std  | 121.08   |
# | loss/bellman_error | 0.90274  |
# | misc/q             | 25.701   |
# | misc/q_est         | 25.745   |
# | misc/epsilon       | 0.0984   |
# | misc/timestep      | 1.44e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 47.311   |
# | reward/reward_max  | 267.76   |
# | reward/reward_min  | -163.43  |
# | reward/reward_std  | 147.2    |
# | loss/bellman_error | 0.93268  |
# | misc/q             | 25.644   |
# | misc/q_est         | 25.674   |
# | misc/epsilon       | 0.0928   |
# | misc/timestep      | 1.48e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 30.671   |
# | reward/reward_max  | 248.23   |
# | reward/reward_min  | -177.88  |
# | reward/reward_std  | 123.38   |
# | loss/bellman_error | 0.92165  |
# | misc/q             | 25.694   |
# | misc/q_est         | 25.702   |
# | misc/epsilon       | 0.0872   |
# | misc/timestep      | 1.52e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 86.327   |
# | reward/reward_max  | 231.62   |
# | reward/reward_min  | -52.819  |
# | reward/reward_std  | 103.11   |
# | loss/bellman_error | 0.91945  |
# | misc/q             | 25.298   |
# | misc/q_est         | 25.332   |
# | misc/epsilon       | 0.0816   |
# | misc/timestep      | 1.56e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 58.753   |
# | reward/reward_max  | 237.89   |
# | reward/reward_min  | -92.831  |
# | reward/reward_std  | 122.87   |
# | loss/bellman_error | 0.9144   |
# | misc/q             | 24.669   |
# | misc/q_est         | 24.669   |
# | misc/epsilon       | 0.076    |
# | misc/timestep      | 1.6e+05  |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 65.113   |
# | reward/reward_max  | 182.19   |
# | reward/reward_min  | -82.661  |
# | reward/reward_std  | 94.059   |
# | loss/bellman_error | 0.93666  |
# | misc/q             | 23.684   |
# | misc/q_est         | 23.672   |
# | misc/epsilon       | 0.0704   |
# | misc/timestep      | 1.64e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 36.425   |
# | reward/reward_max  | 160.55   |
# | reward/reward_min  | -51.263  |
# | reward/reward_std  | 70.706   |
# | loss/bellman_error | 0.90087  |
# | misc/q             | 22.969   |
# | misc/q_est         | 22.964   |
# | misc/epsilon       | 0.0648   |
# | misc/timestep      | 1.68e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 84.547   |
# | reward/reward_max  | 254.27   |
# | reward/reward_min  | -120.54  |
# | reward/reward_std  | 133.14   |
# | loss/bellman_error | 0.93942  |
# | misc/q             | 22.27    |
# | misc/q_est         | 22.256   |
# | misc/epsilon       | 0.0592   |
# | misc/timestep      | 1.72e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 87.336   |
# | reward/reward_max  | 218.21   |
# | reward/reward_min  | -63.28   |
# | reward/reward_std  | 102.24   |
# | loss/bellman_error | 0.94987  |
# | misc/q             | 21.819   |
# | misc/q_est         | 21.777   |
# | misc/epsilon       | 0.0536   |
# | misc/timestep      | 1.76e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 99.174   |
# | reward/reward_max  | 234.25   |
# | reward/reward_min  | -51.403  |
# | reward/reward_std  | 107.94   |
# | loss/bellman_error | 0.93707  |
# | misc/q             | 21.374   |
# | misc/q_est         | 21.329   |
# | misc/epsilon       | 0.048    |
# | misc/timestep      | 1.8e+05  |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 8.627    |
# | reward/reward_max  | 267.92   |
# | reward/reward_min  | -621.67  |
# | reward/reward_std  | 216.32   |
# | loss/bellman_error | 0.92982  |
# | misc/q             | 21.089   |
# | misc/q_est         | 21.064   |
# | misc/epsilon       | 0.0424   |
# | misc/timestep      | 1.84e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 159.23   |
# | reward/reward_max  | 276.88   |
# | reward/reward_min  | -5.3442  |
# | reward/reward_std  | 109.43   |
# | loss/bellman_error | 0.91274  |
# | misc/q             | 20.577   |
# | misc/q_est         | 20.552   |
# | misc/epsilon       | 0.0368   |
# | misc/timestep      | 1.88e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 135.95   |
# | reward/reward_max  | 287.6    |
# | reward/reward_min  | -33.863  |
# | reward/reward_std  | 114.7    |
# | loss/bellman_error | 0.90568  |
# | misc/q             | 20.007   |
# | misc/q_est         | 19.984   |
# | misc/epsilon       | 0.0312   |
# | misc/timestep      | 1.92e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 150.83   |
# | reward/reward_max  | 251.62   |
# | reward/reward_min  | -9.071   |
# | reward/reward_std  | 101.96   |
# | loss/bellman_error | 0.84759  |
# | misc/q             | 19.428   |
# | misc/q_est         | 19.387   |
# | misc/epsilon       | 0.0256   |
# | misc/timestep      | 1.96e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 113.39   |
# | reward/reward_max  | 243.39   |
# | reward/reward_min  | -21.629  |
# | reward/reward_std  | 99.739   |
# | loss/bellman_error | 0.82221  |
# | misc/q             | 18.915   |
# | misc/q_est         | 18.872   |
# | misc/epsilon       | 0.02     |
# | misc/timestep      | 2e+05    |
# ---------------------------------

# %%
env = make_env("LunarLander-v2", monitor=True)
obs = env.reset()
while True:
    obs = torch.FloatTensor(obs).unsqueeze(0)
    act = agent.pick_action(obs, force_greedy=True)
    obs, rew, done, info = env.step(act)
    if done: break
env.close()

HTML(data=get_html_video_string(env.file_infix))
# Out:
# <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video></video>

# %%
plt.figure(dpi=300)
df = pd.read_csv(str(log_root / "lunarlander-v2" / "logs_dqn.csv"), sep=";")
plot_progress(df)

# %% [markdown]
# ## Double DQN

# %% [markdown]
# One of the main drawbacks of vanila DQN is that it overestimates Q-values. More details could be found in the original paper. In a couple of words, we have to estimate an expecation of maximum, not a maximum of expectations as we do in vanila DQN. The trick is to use the second network for the updates (we use target network for this):
#
# $$y = r + \gamma Q_{target}(s^\prime, \text{argmax}_a Q(s^\prime, a) )$$
#
# Compared to
#
# $$y = r + \gamma Q_{target}(s^\prime, \text{argmax}_a Q_{target}(s^\prime, a) )$$
#
# from vanila DQN. Which is the same as:
#
# $$y = r + \gamma \text{max}_a Q_{target}(s^\prime, a)$$
#
# Double Q-learning paper: https://papers.nips.cc/paper/3964-double-q-learning <br>
# Double DQN paper: https://arxiv.org/abs/1509.06461

# %% [markdown]
#  Now, let's try it for the LunarLander environment:

# %%
env = make_env("LunarLander-v2", SEED)

value_network = get_network("mlp")(
    env.observation_space.shape[0],
    256,
    env.action_space.n)

agent = DQN(
    value_network,
    env.action_space,
    eps=.5,
    eps_decay=(.5 - .02) / 10**5 / 2,
    batch_size=64,
    learning_rate=8e-4,
    discount_factor=.99,
    double=True
)

# %%
agent = train(
    agent,
    env,
    log_dir=log_root / "lunarlander-v2",
    prefix="_double_dqn",
    buffer_size=10**5,
    n_steps=2*10**5,
    warmup_steps=10000,
    target_update_every=500,
    log_every=4000,
    save_every=1000
)
# Out:
# ---------------------------------
# | reward/reward_mean | -187.82  |
# | reward/reward_max  | -8.3108  |
# | reward/reward_min  | -520.72  |
# | reward/reward_std  | 110.5    |
# | loss/bellman_error | 1.597    |
# | misc/q             | -1.7561  |
# | misc/q_est         | -1.0705  |
# | misc/epsilon       | 0.4712   |
# | misc/timestep      | 12000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -74.828  |
# | reward/reward_max  | 20.458   |
# | reward/reward_min  | -257.31  |
# | reward/reward_std  | 82.865   |
# | loss/bellman_error | 1.371    |
# | misc/q             | 0.70354  |
# | misc/q_est         | 1.1949   |
# | misc/epsilon       | 0.4616   |
# | misc/timestep      | 16000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -16.912  |
# | reward/reward_max  | 102.11   |
# | reward/reward_min  | -101.43  |
# | reward/reward_std  | 55.427   |
# | loss/bellman_error | 1.4846   |
# | misc/q             | 5.3567   |
# | misc/q_est         | 5.6727   |
# | misc/epsilon       | 0.452    |
# | misc/timestep      | 20000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -29.561  |
# | reward/reward_max  | 39.542   |
# | reward/reward_min  | -84.198  |
# | reward/reward_std  | 33.511   |
# | loss/bellman_error | 1.6326   |
# | misc/q             | 11.15    |
# | misc/q_est         | 11.34    |
# | misc/epsilon       | 0.4424   |
# | misc/timestep      | 24000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 5.0882   |
# | reward/reward_max  | 54.048   |
# | reward/reward_min  | -67.783  |
# | reward/reward_std  | 38.156   |
# | loss/bellman_error | 1.7432   |
# | misc/q             | 14.959   |
# | misc/q_est         | 15.035   |
# | misc/epsilon       | 0.4328   |
# | misc/timestep      | 28000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -36.666  |
# | reward/reward_max  | 41.247   |
# | reward/reward_min  | -184.97  |
# | reward/reward_std  | 68.958   |
# | loss/bellman_error | 1.8605   |
# | misc/q             | 17.019   |
# | misc/q_est         | 17.031   |
# | misc/epsilon       | 0.4232   |
# | misc/timestep      | 32000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -35.855  |
# | reward/reward_max  | 64.965   |
# | reward/reward_min  | -178.02  |
# | reward/reward_std  | 66.863   |
# | loss/bellman_error | 1.9868   |
# | misc/q             | 17.87    |
# | misc/q_est         | 17.741   |
# | misc/epsilon       | 0.4136   |
# | misc/timestep      | 36000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -22.275  |
# | reward/reward_max  | 53.066   |
# | reward/reward_min  | -155.24  |
# | reward/reward_std  | 48.717   |
# | loss/bellman_error | 2.0206   |
# | misc/q             | 18.224   |
# | misc/q_est         | 18.085   |
# | misc/epsilon       | 0.404    |
# | misc/timestep      | 40000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 5.9105   |
# | reward/reward_max  | 85.25    |
# | reward/reward_min  | -67.493  |
# | reward/reward_std  | 46.888   |
# | loss/bellman_error | 2.1679   |
# | misc/q             | 18.05    |
# | misc/q_est         | 17.789   |
# | misc/epsilon       | 0.3944   |
# | misc/timestep      | 44000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -24.039  |
# | reward/reward_max  | 193.51   |
# | reward/reward_min  | -148.99  |
# | reward/reward_std  | 84.208   |
# | loss/bellman_error | 2.3911   |
# | misc/q             | 16.874   |
# | misc/q_est         | 16.521   |
# | misc/epsilon       | 0.3848   |
# | misc/timestep      | 48000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 41.852   |
# | reward/reward_max  | 52.426   |
# | reward/reward_min  | 24.144   |
# | reward/reward_std  | 11.336   |
# | loss/bellman_error | 2.6608   |
# | misc/q             | 16.969   |
# | misc/q_est         | 16.518   |
# | misc/epsilon       | 0.3752   |
# | misc/timestep      | 52000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -22.707  |
# | reward/reward_max  | 23.339   |
# | reward/reward_min  | -150.55  |
# | reward/reward_std  | 57.229   |
# | loss/bellman_error | 2.6975   |
# | misc/q             | 16.338   |
# | misc/q_est         | 15.835   |
# | misc/epsilon       | 0.3656   |
# | misc/timestep      | 56000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -3.1608  |
# | reward/reward_max  | 52.501   |
# | reward/reward_min  | -64.76   |
# | reward/reward_std  | 34.114   |
# | loss/bellman_error | 2.806    |
# | misc/q             | 17.007   |
# | misc/q_est         | 16.519   |
# | misc/epsilon       | 0.356    |
# | misc/timestep      | 60000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 19.38    |
# | reward/reward_max  | 94.572   |
# | reward/reward_min  | -71.425  |
# | reward/reward_std  | 48.45    |
# | loss/bellman_error | 2.8036   |
# | misc/q             | 18.524   |
# | misc/q_est         | 17.952   |
# | misc/epsilon       | 0.3464   |
# | misc/timestep      | 64000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 58.111   |
# | reward/reward_max  | 97.568   |
# | reward/reward_min  | -2.3049  |
# | reward/reward_std  | 36.983   |
# | loss/bellman_error | 2.7532   |
# | misc/q             | 19.763   |
# | misc/q_est         | 19.238   |
# | misc/epsilon       | 0.3368   |
# | misc/timestep      | 68000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 52.701   |
# | reward/reward_max  | 239.29   |
# | reward/reward_min  | -158.45  |
# | reward/reward_std  | 116.52   |
# | loss/bellman_error | 2.8959   |
# | misc/q             | 20.306   |
# | misc/q_est         | 19.76    |
# | misc/epsilon       | 0.3272   |
# | misc/timestep      | 72000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 10.513   |
# | reward/reward_max  | 70.461   |
# | reward/reward_min  | -50.126  |
# | reward/reward_std  | 49.745   |
# | loss/bellman_error | 2.7464   |
# | misc/q             | 21.52    |
# | misc/q_est         | 21.044   |
# | misc/epsilon       | 0.3176   |
# | misc/timestep      | 76000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 99.71    |
# | reward/reward_max  | 123.81   |
# | reward/reward_min  | 79.977   |
# | reward/reward_std  | 19.865   |
# | loss/bellman_error | 2.8258   |
# | misc/q             | 22.202   |
# | misc/q_est         | 21.717   |
# | misc/epsilon       | 0.308    |
# | misc/timestep      | 80000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 98.065   |
# | reward/reward_max  | 141.56   |
# | reward/reward_min  | 29.57    |
# | reward/reward_std  | 37.859   |
# | loss/bellman_error | 2.8337   |
# | misc/q             | 22.757   |
# | misc/q_est         | 22.303   |
# | misc/epsilon       | 0.2984   |
# | misc/timestep      | 84000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 74.733   |
# | reward/reward_max  | 109.45   |
# | reward/reward_min  | 13.929   |
# | reward/reward_std  | 36.587   |
# | loss/bellman_error | 2.7635   |
# | misc/q             | 23.264   |
# | misc/q_est         | 22.743   |
# | misc/epsilon       | 0.2888   |
# | misc/timestep      | 88000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 62.01    |
# | reward/reward_max  | 118.99   |
# | reward/reward_min  | 3.7914   |
# | reward/reward_std  | 48.035   |
# | loss/bellman_error | 2.6969   |
# | misc/q             | 23.641   |
# | misc/q_est         | 23.088   |
# | misc/epsilon       | 0.2792   |
# | misc/timestep      | 92000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 134.1    |
# | reward/reward_max  | 167.39   |
# | reward/reward_min  | 109.94   |
# | reward/reward_std  | 23.904   |
# | loss/bellman_error | 2.6571   |
# | misc/q             | 23.882   |
# | misc/q_est         | 23.418   |
# | misc/epsilon       | 0.2696   |
# | misc/timestep      | 96000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 115.07   |
# | reward/reward_max  | 173.98   |
# | reward/reward_min  | 36.548   |
# | reward/reward_std  | 53.514   |
# | loss/bellman_error | 2.6423   |
# | misc/q             | 23.951   |
# | misc/q_est         | 23.436   |
# | misc/epsilon       | 0.26     |
# | misc/timestep      | 1e+05    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 81.917   |
# | reward/reward_max  | 157.75   |
# | reward/reward_min  | -45.182  |
# | reward/reward_std  | 68.619   |
# | loss/bellman_error | 2.574    |
# | misc/q             | 25.117   |
# | misc/q_est         | 24.651   |
# | misc/epsilon       | 0.2504   |
# | misc/timestep      | 1.04e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 98.234   |
# | reward/reward_max  | 135.16   |
# | reward/reward_min  | 43.33    |
# | reward/reward_std  | 33.944   |
# | loss/bellman_error | 2.2736   |
# | misc/q             | 26.4     |
# | misc/q_est         | 26.114   |
# | misc/epsilon       | 0.2408   |
# | misc/timestep      | 1.08e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 55.248   |
# | reward/reward_max  | 154.73   |
# | reward/reward_min  | -54.604  |
# | reward/reward_std  | 77.222   |
# | loss/bellman_error | 1.9669   |
# | misc/q             | 27.888   |
# | misc/q_est         | 27.722   |
# | misc/epsilon       | 0.2312   |
# | misc/timestep      | 1.12e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 118.16   |
# | reward/reward_max  | 130.11   |
# | reward/reward_min  | 94.164   |
# | reward/reward_std  | 14.104   |
# | loss/bellman_error | 1.7971   |
# | misc/q             | 27.776   |
# | misc/q_est         | 27.674   |
# | misc/epsilon       | 0.2216   |
# | misc/timestep      | 1.16e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 86.907   |
# | reward/reward_max  | 126.27   |
# | reward/reward_min  | 13.229   |
# | reward/reward_std  | 42.254   |
# | loss/bellman_error | 1.721    |
# | misc/q             | 26.29    |
# | misc/q_est         | 26.186   |
# | misc/epsilon       | 0.212    |
# | misc/timestep      | 1.2e+05  |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 114.71   |
# | reward/reward_max  | 236.9    |
# | reward/reward_min  | -41.026  |
# | reward/reward_std  | 89.392   |
# | loss/bellman_error | 1.722    |
# | misc/q             | 25.014   |
# | misc/q_est         | 24.904   |
# | misc/epsilon       | 0.2024   |
# | misc/timestep      | 1.24e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 115.87   |
# | reward/reward_max  | 293.53   |
# | reward/reward_min  | -20.15   |
# | reward/reward_std  | 100.05   |
# | loss/bellman_error | 1.7123   |
# | misc/q             | 24.174   |
# | misc/q_est         | 24.036   |
# | misc/epsilon       | 0.1928   |
# | misc/timestep      | 1.28e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 110.9    |
# | reward/reward_max  | 250.17   |
# | reward/reward_min  | -34.371  |
# | reward/reward_std  | 94.105   |
# | loss/bellman_error | 1.6682   |
# | misc/q             | 23.798   |
# | misc/q_est         | 23.679   |
# | misc/epsilon       | 0.1832   |
# | misc/timestep      | 1.32e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 17.597   |
# | reward/reward_max  | 133.21   |
# | reward/reward_min  | -283.67  |
# | reward/reward_std  | 174.19   |
# | loss/bellman_error | 1.6343   |
# | misc/q             | 23.722   |
# | misc/q_est         | 23.606   |
# | misc/epsilon       | 0.1736   |
# | misc/timestep      | 1.36e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 200.03   |
# | reward/reward_max  | 300.22   |
# | reward/reward_min  | 100.24   |
# | reward/reward_std  | 70.892   |
# | loss/bellman_error | 1.569    |
# | misc/q             | 23.259   |
# | misc/q_est         | 23.185   |
# | misc/epsilon       | 0.164    |
# | misc/timestep      | 1.4e+05  |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 164.6    |
# | reward/reward_max  | 254.46   |
# | reward/reward_min  | 10.899   |
# | reward/reward_std  | 91.159   |
# | loss/bellman_error | 1.4878   |
# | misc/q             | 22.879   |
# | misc/q_est         | 22.795   |
# | misc/epsilon       | 0.1544   |
# | misc/timestep      | 1.44e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 172.41   |
# | reward/reward_max  | 244.98   |
# | reward/reward_min  | 27.336   |
# | reward/reward_std  | 78.821   |
# | loss/bellman_error | 1.4213   |
# | misc/q             | 22.45    |
# | misc/q_est         | 22.341   |
# | misc/epsilon       | 0.1448   |
# | misc/timestep      | 1.48e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 210.87   |
# | reward/reward_max  | 241.18   |
# | reward/reward_min  | 119.79   |
# | reward/reward_std  | 45.901   |
# | loss/bellman_error | 1.425    |
# | misc/q             | 22.598   |
# | misc/q_est         | 22.475   |
# | misc/epsilon       | 0.1352   |
# | misc/timestep      | 1.52e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 198.98   |
# | reward/reward_max  | 269.62   |
# | reward/reward_min  | 115.53   |
# | reward/reward_std  | 62.012   |
# | loss/bellman_error | 1.382    |
# | misc/q             | 22.689   |
# | misc/q_est         | 22.568   |
# | misc/epsilon       | 0.1256   |
# | misc/timestep      | 1.56e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 215.23   |
# | reward/reward_max  | 262.23   |
# | reward/reward_min  | 94.981   |
# | reward/reward_std  | 63.176   |
# | loss/bellman_error | 1.361    |
# | misc/q             | 22.961   |
# | misc/q_est         | 22.82    |
# | misc/epsilon       | 0.116    |
# | misc/timestep      | 1.6e+05  |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 190.09   |
# | reward/reward_max  | 271.18   |
# | reward/reward_min  | -1.5226  |
# | reward/reward_std  | 95.167   |
# | loss/bellman_error | 1.2789   |
# | misc/q             | 23.31    |
# | misc/q_est         | 23.19    |
# | misc/epsilon       | 0.1064   |
# | misc/timestep      | 1.64e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 121.31   |
# | reward/reward_max  | 269.35   |
# | reward/reward_min  | -197.01  |
# | reward/reward_std  | 155.81   |
# | loss/bellman_error | 1.1808   |
# | misc/q             | 22.858   |
# | misc/q_est         | 22.737   |
# | misc/epsilon       | 0.0968   |
# | misc/timestep      | 1.68e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 238.92   |
# | reward/reward_max  | 299.57   |
# | reward/reward_min  | 144.06   |
# | reward/reward_std  | 48.351   |
# | loss/bellman_error | 1.1019   |
# | misc/q             | 23.201   |
# | misc/q_est         | 23.099   |
# | misc/epsilon       | 0.0872   |
# | misc/timestep      | 1.72e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 240.83   |
# | reward/reward_max  | 290.56   |
# | reward/reward_min  | 152.49   |
# | reward/reward_std  | 38.033   |
# | loss/bellman_error | 1.0313   |
# | misc/q             | 22.812   |
# | misc/q_est         | 22.681   |
# | misc/epsilon       | 0.0776   |
# | misc/timestep      | 1.76e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 208.43   |
# | reward/reward_max  | 236.64   |
# | reward/reward_min  | 128.38   |
# | reward/reward_std  | 46.24    |
# | loss/bellman_error | 0.94862  |
# | misc/q             | 22.491   |
# | misc/q_est         | 22.381   |
# | misc/epsilon       | 0.068    |
# | misc/timestep      | 1.8e+05  |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 237.06   |
# | reward/reward_max  | 280.08   |
# | reward/reward_min  | 179.66   |
# | reward/reward_std  | 27.251   |
# | loss/bellman_error | 0.84034  |
# | misc/q             | 22.369   |
# | misc/q_est         | 22.269   |
# | misc/epsilon       | 0.0584   |
# | misc/timestep      | 1.84e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 237.36   |
# | reward/reward_max  | 280.66   |
# | reward/reward_min  | 159.33   |
# | reward/reward_std  | 37.729   |
# | loss/bellman_error | 0.81328  |
# | misc/q             | 21.908   |
# | misc/q_est         | 21.796   |
# | misc/epsilon       | 0.0488   |
# | misc/timestep      | 1.88e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 193.05   |
# | reward/reward_max  | 265.75   |
# | reward/reward_min  | 124.76   |
# | reward/reward_std  | 56.502   |
# | loss/bellman_error | 0.74617  |
# | misc/q             | 21.542   |
# | misc/q_est         | 21.426   |
# | misc/epsilon       | 0.0392   |
# | misc/timestep      | 1.92e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 213.62   |
# | reward/reward_max  | 274.43   |
# | reward/reward_min  | 113.38   |
# | reward/reward_std  | 65.421   |
# | loss/bellman_error | 0.69516  |
# | misc/q             | 21.24    |
# | misc/q_est         | 21.136   |
# | misc/epsilon       | 0.0296   |
# | misc/timestep      | 1.96e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 204.55   |
# | reward/reward_max  | 263.3    |
# | reward/reward_min  | 27.701   |
# | reward/reward_std  | 77.964   |
# | loss/bellman_error | 0.66646  |
# | misc/q             | 21.251   |
# | misc/q_est         | 21.141   |
# | misc/epsilon       | 0.02     |
# | misc/timestep      | 2e+05    |
# ---------------------------------

# %%
env = make_env("LunarLander-v2", monitor=True)
obs = env.reset()
while True:
    obs = torch.FloatTensor(obs).unsqueeze(0)
    act = agent.pick_action(obs, force_greedy=True)
    obs, rew, done, info = env.step(act)
    if done: break
env.close()

HTML(data=get_html_video_string(env.file_infix))
# Out:
# <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video></video>

# %% [markdown]
# You should obtain better curve for Double DQN, however it is not always the case. For such environent the improvement could be neglectable. Although, you have to at least reach the same performance.
# You may want to compare the performance on CartPole as, unlike LunarLander , its reward function is dense. However, it may be too simple to reveal any difference.

# %%
plt.figure(dpi=300)
df = pd.read_csv(str(log_root / "lunarlander-v2" / "logs_dqn.csv"), sep=";")
df_double = pd.read_csv(str(log_root / "lunarlander-v2" / "logs_double_dqn.csv"), sep=";")
plot_progress(df, "DQN")
plot_progress(df_double, "Double DQN")

# %% [markdown]
# ### Look at the graphs of estimated Q values by DQN and Double DQN. Could you describe what's happening?

# %%
plt.figure(dpi=300)
plt.xlabel("Timestep")
plt.ylabel("estimated Q value")
plt.plot(df['misc/timestep'], df['misc/q_est'], label="DQN")
plt.plot(df_double['misc/timestep'], df_double['misc/q_est'], label="Double DQN")
plt.legend(loc="best");

# %% [markdown]
# # ATARI Pong
#
# In this section, you can try the algorithm on the larger problem from Atari suit. The training procedure is computationally cumbersome, so that ideally one may want to use GPU and powerful CPU for this task. Also note, that usually people choose larger `buffer_size` for this benchmark, which may consume anormous amount of RAM. To avoid the memory overflow, you may consider to use lossless compression algorithm to save a lot of space by compressing observations. See RLLib for example.
#
# If you decided to go through the task, note, that typical choice of hyperparameters for Atari differs from previous ones. See RLLib's configs, for example, as a reference.

# %%
# !pip install 'gym[atari]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[atari] in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (1.15.0)
# Requirement already satisfied: pyglet<=1.3.2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (1.3.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (1.7.3)
# Requirement already satisfied: cloudpickle~=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (1.2.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (4.6.0.66)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (7.1.2)
# Requirement already satisfied: atari-py~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[atari]) (0.2.9)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.3.2,>=1.2.0->gym[atari]) (0.16.0)

# %%
from lib import atari_wrappers
from lib.utils import TransposeImage

# %%
! wget http://www.atarimania.com/roms/Roms.rar
! mkdir /content/ROM/
! unrar e /content/Roms.rar /content/ROM/
! python -m atari_py.import_roms /content/ROM/

# %%
def make_env(name, seed=None, monitor=False):
    env = gym.make(name)

    is_atari = hasattr(gym.envs, 'atari') and isinstance(
        env.unwrapped, gym.envs.atari.atari_env.AtariEnv)

    if is_atari:
        max_epi_steps = 108000
        if max_epi_steps < 0:
            max_epi_steps = None

        env = atari_wrappers.make_atari(name, max_epi_steps)
        env = atari_wrappers.wrap_deepmind(env, True, True, True, True)
        env = TransposeImage(env, op=[2, 0, 1])
        
    if monitor:
        env = wrappers.Monitor(env, "./gym-results", force=True)
    if seed:
        env.seed(seed)


    return env

env = gym.make("PongNoFrameskip-v0")
env.action_space, env.observation_space.dtype
# Out:
# (Discrete(6), dtype('uint8'))

# %%
env = make_env("PongNoFrameskip-v0")

value_network = get_network("vision")(
    env.observation_space.shape[0],
    128,
    env.action_space.n)

agent = DQN(
    value_network,
    env.action_space,
    eps=.1,
    eps_decay=(.1 - .01) / 10**5 / 2,
    batch_size=128,
    learning_rate=1e-3,
    discount_factor=.99,
    double=True,
    # cuda=True,
)

# %%
agent = train(
    agent,
    env,
    log_dir=log_root / "pong-v0",
    prefix="_double_dqn",
    buffer_size=5*10**5,
    n_steps=4*10**5,
    warmup_steps=10000,
    target_update_every=1000,
    log_every=4000,
    save_every=1000,
    update_every=4
)

# %%
env = make_env("PongNoFrameskip-v0")
obs = env.reset()
while True:
    obs = torch.FloatTensor(obs).unsqueeze(0)
    act = agent.pick_action(obs, force_greedy=True)
    obs, rew, done, info = env.step(act)
    if done: break
env.close()

HTML(data=get_html_video_string(env.file_infix))

# %%
plt.figure(dpi=300)
df = pd.read_csv(str(log_root / "pong-v0" / "logs_double_dqn.csv"), sep=";")
plot_progress(df)
