# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import io
import base64
import random

import gym
from gym import wrappers
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import torch

from lib import get_network
from lib.agent import DQN
from lib.logging import Logger
from lib.rollout import ReplayBuffer

from IPython.display import HTML

plt.style.use('seaborn')
# Out:
# /tmp/ipykernel_96297/4255331757.py:20: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ### In this assignment you are going to:
# * implement DQN and doubleDQN
# * use them on CartPole, LunarLander and (Optionally) BreakOut environments
#
# ### We use PyTorch for neural networks. If you are new to PyTorch see tutorials:
# https://pytorch.org/tutorials/ <br>
# https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html

# %% [markdown]
# # CartPole

# %% [markdown]
# First, let's take a closer look at the environment.

# %%
def make_env(name, seed=None, monitor=False):
    env = gym.make(name)
    if monitor:
        env = wrappers.Monitor(env, "./gym-results", force=True)
    if seed:
        env.seed(seed)
    return env

# %%
def get_html_video_string(infix):
    video = io.open(
        f'./gym-results/openaigym.video.{infix}.video000000.mp4',
        'r+b').read()
    encoded = base64.b64encode(video)
    dec_str = encoded.decode('ascii')
    src_tag = f'<source src="data:video/mp4;base64,{dec_str}" type="video/mp4" /></video>'
    html = f'<video width="360" height="auto" alt="test" controls>{src_tag}</video>'
    return html

# %%
SEED = 0xCEEEEEEB
random.seed(SEED)
torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
log_root = Path("results")
log_root.mkdir(exist_ok=True)

# %% [markdown]
# The next cell will embed a video of random policy playing CartPole-v1

# %%
env = make_env("CartPole-v1", monitor=True)
env.reset()
while True:
    action = env.action_space.sample()
    if env.step(action)[2]: break
env.close()

HTML(data=get_html_video_string(env.file_infix))
# Out:
# <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video></video>

# %% [markdown]
# ## Training loop
# Here's the definition of a function that implements training loop. We'll get through its elements soon.
# Although, note that we use a warmup techinque to fill the buffer in the beginning of a training procedure.
#
# The loop consists of:
# * Picking an action using the policy:
# $$a = \text{argmax}_a Q(s, a)$$
# * Sending the action to environment (`step`)
# * Sampling N examples from the ReplayBuffer:
# $$ (s_i, a_i, s^\prime_i, r_i)_{i=1,..,N} $$
# * Updating Q-network by minimizing the loss:
# $$y = r_i + \gamma \text{max}_a Q_{target}(s^{\prime}_i, a)$$
#
# $$L_i = \text{Loss}(Q(s_i, a_i), y)$$
# $$L = \frac{1}{N} \sum_i L_i \rightarrow min,$$
# where $\text{Loss}$ is $L_2$ loss or Huber loss
# * Updating target network every `target_update_every` iteration:
# $$\theta^\prime \leftarrow \theta \tau + \theta^\prime (1 - \tau)$$
# where $\theta^\prime$ - paremeters of $Q_{target}$ network, <br>
# $\theta$ - paremeters of $Q$ network,<br>
# $\tau \in [0, 1]$
#
# Note, that we also use a logger that writes training info to `CSV` file, `TensorBoard` and `stdout`. We use `CSV` and `stdout` throughout the notebook, but you can use TB for convenience.

# %% [markdown]
# #### Task 0: Implement ReplayBuffer from `lib/rollout.py`

# %%
def train(
    agent,
    env,
    *,
    log_dir,
    prefix,
    buffer_size,
    n_steps,
    warmup_steps,
    target_update_every,
    log_every,
    save_every
):
    """Training loop procedure.
    
    Arguments:
        agent: DQN object.
        env: Gym environment.
        log_dir: PathLib path to logging dir.
        prefix: Prefix for the experiment.
        buffer_size: Maximum capacity of the replay buffer.
        n_steps: Total number of training iterations.
        warmup_steps: Number of first iterations that employ random policy.
        target_update_every: Number of iterations between target network updates.
        log_every: Log frequency
        save_every: Save frequency
        
    Returns the best agent after training.
    """
    best_agent = agent.copy()
    best_rew = -np.inf
    
    logger = Logger(log_dir, prefix)
    episode_reward = []
    memory = ReplayBuffer(buffer_size)
    
    obs_cur = env.reset()
    for i in range(n_steps + 1):
        if i > warmup_steps:
            obs = torch.FloatTensor(obs_cur).unsqueeze(0)
            act = agent.pick_action(obs)
        else:
            act = env.action_space.sample()

        obs_prev = obs_cur
        obs_cur, rew, done, info = env.step(act)
        episode_reward.append(rew)

        memory.push(obs_prev, act, obs_cur, rew, done)

        if done:
            rew = np.sum(episode_reward)
            episode_reward = []
            logger.log_arr_kv("reward/reward", rew)
            obs_cur = env.reset()

        if i > warmup_steps:

            loss, q, q_est = agent.update_value(memory)
            logger.log_arr_kv("loss/bellman_error_t", loss)
            logger.log_arr_kv("misc/q_t", q)
            logger.log_arr_kv("misc/q_est_t", q_est)

            if i % target_update_every == 0:
                agent.update_target()

            if i % log_every == 0:
                rew = logger.reduce_arr_kv("reward/reward", "reward/reward_mean", np.mean)
                if rew > best_rew:
                    best_agent = agent.copy()
                
                logger.reduce_arr_kv("reward/reward", "reward/reward_max", np.max)
                logger.reduce_arr_kv("reward/reward", "reward/reward_min", np.min)
                logger.reduce_arr_kv("reward/reward", "reward/reward_std", np.std)
                logger.reduce_arr_kv("loss/bellman_error_t", "loss/bellman_error", np.mean)
                logger.reduce_arr_kv("misc/q_t", "misc/q", np.mean)
                logger.reduce_arr_kv("misc/q_est_t", "misc/q_est", np.mean)
                logger.log_kv("misc/epsilon", agent.eps)
                logger.log_kv("misc/timestep", i)
                logger.write_logs(skip_arrs=True)
                
                

            if i % save_every == 0:
                num = i // save_every + 1
                save_dir = log_dir / "checkpoints"
                save_dir.mkdir(exist_ok=True)
                agent.save_to(save_dir, prefix=hex(num)[2:].upper())

        agent.update_eps()
    return best_agent

# %% [markdown]
# # Implementation
# #### Task 1: Implement MLP network in `lib/network.py`
# #### Task 2: Implement DQN in `lib/agent.py`
#
# Now, run the next two cells. You should obtain the highest (500) reward in less than 100000 steps

# %% [markdown]
# Note! You can try to use small `target_update_every`. E.g. value of 1 corresponds to fitted Q-iteration. The expected outcome is unstable or even divergent behaviour

# %%
env = make_env("CartPole-v1", SEED)

value_network = get_network("mlp")(
    env.observation_space.shape[0],
    64,
    env.action_space.n)

agent = DQN(
    value_network,
    env.action_space,
    eps=.2,
    eps_decay=(.2 - .02) / 10**5,
    batch_size=32,
    learning_rate=5e-4,
    discount_factor=.99
)

# %%
agent = train(
    agent,
    env,
    log_dir=log_root / "cartpole-v1",
    prefix="_dqn",
    buffer_size=5 * 10**4,
    n_steps=10**5,
    warmup_steps=1000,
    target_update_every=500,
    log_every=500,
    save_every=1000,
)
# Out:
# ---------------------------------
# | reward/reward_mean | 16.25    |
# | reward/reward_max  | 73       |
# | reward/reward_min  | 8        |
# | reward/reward_std  | 10.662   |
# | loss/bellman_error | 0.10292  |
# | misc/q             | 1.2194   |
# | misc/q_est         | 0.96444  |
# | misc/epsilon       | 0.1973   |
# | misc/timestep      | 1500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 10.826   |
# | reward/reward_max  | 16       |
# | reward/reward_min  | 8        |
# | reward/reward_std  | 1.7853   |
# | loss/bellman_error | 0.077536 |
# | misc/q             | 2.158    |
# | misc/q_est         | 2.1002   |
# | misc/epsilon       | 0.1964   |
# | misc/timestep      | 2000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 11.651   |
# | reward/reward_max  | 32       |
# | reward/reward_min  | 8        |
# | reward/reward_std  | 4.5794   |
# | loss/bellman_error | 0.11354  |
# | misc/q             | 3.0153   |
# | misc/q_est         | 3.0272   |
# | misc/epsilon       | 0.1955   |
# | misc/timestep      | 2500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 24.8     |
# | reward/reward_max  | 98       |
# | reward/reward_min  | 8        |
# | reward/reward_std  | 22.487   |
# | loss/bellman_error | 0.14945  |
# | misc/q             | 3.8616   |
# | misc/q_est         | 3.9263   |
# | misc/epsilon       | 0.1946   |
# | misc/timestep      | 3000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 31.643   |
# | reward/reward_max  | 85       |
# | reward/reward_min  | 9        |
# | reward/reward_std  | 20.141   |
# | loss/bellman_error | 0.17172  |
# | misc/q             | 4.7038   |
# | misc/q_est         | 4.7997   |
# | misc/epsilon       | 0.1937   |
# | misc/timestep      | 3500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 68.5     |
# | reward/reward_max  | 160      |
# | reward/reward_min  | 39       |
# | reward/reward_std  | 36.304   |
# | loss/bellman_error | 0.18015  |
# | misc/q             | 5.6204   |
# | misc/q_est         | 5.7364   |
# | misc/epsilon       | 0.1928   |
# | misc/timestep      | 4000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 61.625   |
# | reward/reward_max  | 86       |
# | reward/reward_min  | 45       |
# | reward/reward_std  | 12.359   |
# | loss/bellman_error | 0.2061   |
# | misc/q             | 6.585    |
# | misc/q_est         | 6.7331   |
# | misc/epsilon       | 0.1919   |
# | misc/timestep      | 4500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 56       |
# | reward/reward_max  | 68       |
# | reward/reward_min  | 43       |
# | reward/reward_std  | 9.1378   |
# | loss/bellman_error | 0.22994  |
# | misc/q             | 7.5075   |
# | misc/q_est         | 7.6832   |
# | misc/epsilon       | 0.191    |
# | misc/timestep      | 5000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 72       |
# | reward/reward_max  | 90       |
# | reward/reward_min  | 55       |
# | reward/reward_std  | 13.491   |
# | loss/bellman_error | 0.25691  |
# | misc/q             | 8.3765   |
# | misc/q_est         | 8.5817   |
# | misc/epsilon       | 0.1901   |
# | misc/timestep      | 5500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 96.2     |
# | reward/reward_max  | 152      |
# | reward/reward_min  | 60       |
# | reward/reward_std  | 32.326   |
# | loss/bellman_error | 0.27955  |
# | misc/q             | 9.2884   |
# | misc/q_est         | 9.5188   |
# | misc/epsilon       | 0.1892   |
# | misc/timestep      | 6000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 95.6     |
# | reward/reward_max  | 164      |
# | reward/reward_min  | 70       |
# | reward/reward_std  | 34.54    |
# | loss/bellman_error | 0.27414  |
# | misc/q             | 10.196   |
# | misc/q_est         | 10.424   |
# | misc/epsilon       | 0.1883   |
# | misc/timestep      | 6500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 150.67   |
# | reward/reward_max  | 202      |
# | reward/reward_min  | 110      |
# | reward/reward_std  | 38.309   |
# | loss/bellman_error | 0.2798   |
# | misc/q             | 11.109   |
# | misc/q_est         | 11.346   |
# | misc/epsilon       | 0.1874   |
# | misc/timestep      | 7000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 168      |
# | reward/reward_max  | 232      |
# | reward/reward_min  | 126      |
# | reward/reward_std  | 45.986   |
# | loss/bellman_error | 0.32682  |
# | misc/q             | 11.997   |
# | misc/q_est         | 12.28    |
# | misc/epsilon       | 0.1865   |
# | misc/timestep      | 7500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 96.833   |
# | reward/reward_max  | 109      |
# | reward/reward_min  | 79       |
# | reward/reward_std  | 10.351   |
# | loss/bellman_error | 0.31709  |
# | misc/q             | 12.931   |
# | misc/q_est         | 13.21    |
# | misc/epsilon       | 0.1856   |
# | misc/timestep      | 8000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 113.67   |
# | reward/reward_max  | 138      |
# | reward/reward_min  | 87       |
# | reward/reward_std  | 20.886   |
# | loss/bellman_error | 0.33614  |
# | misc/q             | 13.77    |
# | misc/q_est         | 14.067   |
# | misc/epsilon       | 0.1847   |
# | misc/timestep      | 8500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 160      |
# | reward/reward_max  | 170      |
# | reward/reward_min  | 144      |
# | reward/reward_std  | 10.296   |
# | loss/bellman_error | 0.33556  |
# | misc/q             | 14.637   |
# | misc/q_est         | 14.935   |
# | misc/epsilon       | 0.1838   |
# | misc/timestep      | 9000     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 118.5    |
# | reward/reward_max  | 131      |
# | reward/reward_min  | 102      |
# | reward/reward_std  | 10.735   |
# | loss/bellman_error | 0.35307  |
# | misc/q             | 15.455   |
# | misc/q_est         | 15.771   |
# | misc/epsilon       | 0.1829   |
# | misc/timestep      | 9500     |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 102      |
# | reward/reward_max  | 130      |
# | reward/reward_min  | 84       |
# | reward/reward_std  | 15.531   |
# | loss/bellman_error | 0.33564  |
# | misc/q             | 16.347   |
# | misc/q_est         | 16.649   |
# | misc/epsilon       | 0.182    |
# | misc/timestep      | 10000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 113.25   |
# | reward/reward_max  | 125      |
# | reward/reward_min  | 94       |
# | reward/reward_std  | 11.584   |
# | loss/bellman_error | 0.36645  |
# | misc/q             | 17.181   |
# | misc/q_est         | 17.513   |
# | misc/epsilon       | 0.1811   |
# | misc/timestep      | 10500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 105.4    |
# | reward/reward_max  | 124      |
# | reward/reward_min  | 87       |
# | reward/reward_std  | 13.425   |
# | loss/bellman_error | 0.34308  |
# | misc/q             | 18.015   |
# | misc/q_est         | 18.327   |
# | misc/epsilon       | 0.1802   |
# | misc/timestep      | 11000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 95.4     |
# | reward/reward_max  | 115      |
# | reward/reward_min  | 70       |
# | reward/reward_std  | 14.458   |
# | loss/bellman_error | 0.36887  |
# | misc/q             | 18.811   |
# | misc/q_est         | 19.15    |
# | misc/epsilon       | 0.1793   |
# | misc/timestep      | 11500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 114      |
# | reward/reward_max  | 131      |
# | reward/reward_min  | 102      |
# | reward/reward_std  | 10.714   |
# | loss/bellman_error | 0.37977  |
# | misc/q             | 19.624   |
# | misc/q_est         | 19.972   |
# | misc/epsilon       | 0.1784   |
# | misc/timestep      | 12000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 102.2    |
# | reward/reward_max  | 111      |
# | reward/reward_min  | 93       |
# | reward/reward_std  | 7.2498   |
# | loss/bellman_error | 0.36046  |
# | misc/q             | 20.393   |
# | misc/q_est         | 20.725   |
# | misc/epsilon       | 0.1775   |
# | misc/timestep      | 12500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 110.75   |
# | reward/reward_max  | 121      |
# | reward/reward_min  | 102      |
# | reward/reward_std  | 6.9056   |
# | loss/bellman_error | 0.37498  |
# | misc/q             | 21.166   |
# | misc/q_est         | 21.512   |
# | misc/epsilon       | 0.1766   |
# | misc/timestep      | 13000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 106.8    |
# | reward/reward_max  | 110      |
# | reward/reward_min  | 100      |
# | reward/reward_std  | 3.8678   |
# | loss/bellman_error | 0.34909  |
# | misc/q             | 21.996   |
# | misc/q_est         | 22.319   |
# | misc/epsilon       | 0.1757   |
# | misc/timestep      | 13500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 106.25   |
# | reward/reward_max  | 124      |
# | reward/reward_min  | 89       |
# | reward/reward_std  | 12.872   |
# | loss/bellman_error | 0.42458  |
# | misc/q             | 22.651   |
# | misc/q_est         | 23.046   |
# | misc/epsilon       | 0.1748   |
# | misc/timestep      | 14000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 122.75   |
# | reward/reward_max  | 147      |
# | reward/reward_min  | 95       |
# | reward/reward_std  | 21.845   |
# | loss/bellman_error | 0.42594  |
# | misc/q             | 23.442   |
# | misc/q_est         | 23.84    |
# | misc/epsilon       | 0.1739   |
# | misc/timestep      | 14500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 108      |
# | reward/reward_max  | 117      |
# | reward/reward_min  | 99       |
# | reward/reward_std  | 6.3875   |
# | loss/bellman_error | 0.41365  |
# | misc/q             | 24.23    |
# | misc/q_est         | 24.617   |
# | misc/epsilon       | 0.173    |
# | misc/timestep      | 15000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 125      |
# | reward/reward_max  | 141      |
# | reward/reward_min  | 105      |
# | reward/reward_std  | 14.37    |
# | loss/bellman_error | 0.45939  |
# | misc/q             | 24.979   |
# | misc/q_est         | 25.411   |
# | misc/epsilon       | 0.1721   |
# | misc/timestep      | 15500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 129.5    |
# | reward/reward_max  | 151      |
# | reward/reward_min  | 117      |
# | reward/reward_std  | 12.855   |
# | loss/bellman_error | 0.43177  |
# | misc/q             | 25.669   |
# | misc/q_est         | 26.073   |
# | misc/epsilon       | 0.1712   |
# | misc/timestep      | 16000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 114.25   |
# | reward/reward_max  | 119      |
# | reward/reward_min  | 110      |
# | reward/reward_std  | 3.8324   |
# | loss/bellman_error | 0.4246   |
# | misc/q             | 26.436   |
# | misc/q_est         | 26.834   |
# | misc/epsilon       | 0.1703   |
# | misc/timestep      | 16500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 133      |
# | reward/reward_max  | 142      |
# | reward/reward_min  | 120      |
# | reward/reward_std  | 8.1548   |
# | loss/bellman_error | 0.44664  |
# | misc/q             | 27.138   |
# | misc/q_est         | 27.558   |
# | misc/epsilon       | 0.1694   |
# | misc/timestep      | 17000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 177.67   |
# | reward/reward_max  | 202      |
# | reward/reward_min  | 143      |
# | reward/reward_std  | 25.171   |
# | loss/bellman_error | 0.43155  |
# | misc/q             | 27.847   |
# | misc/q_est         | 28.254   |
# | misc/epsilon       | 0.1685   |
# | misc/timestep      | 17500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 127.25   |
# | reward/reward_max  | 157      |
# | reward/reward_min  | 107      |
# | reward/reward_std  | 20.644   |
# | loss/bellman_error | 0.40345  |
# | misc/q             | 28.572   |
# | misc/q_est         | 28.952   |
# | misc/epsilon       | 0.1676   |
# | misc/timestep      | 18000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 174      |
# | reward/reward_max  | 174      |
# | reward/reward_min  | 174      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.43317  |
# | misc/q             | 29.248   |
# | misc/q_est         | 29.657   |
# | misc/epsilon       | 0.1667   |
# | misc/timestep      | 18500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 280.67   |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 164      |
# | reward/reward_std  | 155.2    |
# | loss/bellman_error | 0.42897  |
# | misc/q             | 29.983   |
# | misc/q_est         | 30.389   |
# | misc/epsilon       | 0.1658   |
# | misc/timestep      | 19000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 161.33   |
# | reward/reward_max  | 175      |
# | reward/reward_min  | 141      |
# | reward/reward_std  | 14.659   |
# | loss/bellman_error | 0.41103  |
# | misc/q             | 30.735   |
# | misc/q_est         | 31.124   |
# | misc/epsilon       | 0.1649   |
# | misc/timestep      | 19500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 172      |
# | reward/reward_max  | 199      |
# | reward/reward_min  | 142      |
# | reward/reward_std  | 23.367   |
# | loss/bellman_error | 0.4677   |
# | misc/q             | 31.345   |
# | misc/q_est         | 31.787   |
# | misc/epsilon       | 0.164    |
# | misc/timestep      | 20000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 149.67   |
# | reward/reward_max  | 174      |
# | reward/reward_min  | 126      |
# | reward/reward_std  | 19.602   |
# | loss/bellman_error | 0.45624  |
# | misc/q             | 32.005   |
# | misc/q_est         | 32.437   |
# | misc/epsilon       | 0.1631   |
# | misc/timestep      | 20500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 146.33   |
# | reward/reward_max  | 165      |
# | reward/reward_min  | 124      |
# | reward/reward_std  | 16.938   |
# | loss/bellman_error | 0.47835  |
# | misc/q             | 32.669   |
# | misc/q_est         | 33.123   |
# | misc/epsilon       | 0.1622   |
# | misc/timestep      | 21000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 210.5    |
# | reward/reward_max  | 287      |
# | reward/reward_min  | 134      |
# | reward/reward_std  | 76.5     |
# | loss/bellman_error | 0.46013  |
# | misc/q             | 33.364   |
# | misc/q_est         | 33.801   |
# | misc/epsilon       | 0.1613   |
# | misc/timestep      | 21500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 160.5    |
# | reward/reward_max  | 238      |
# | reward/reward_min  | 127      |
# | reward/reward_std  | 45.489   |
# | loss/bellman_error | 0.42653  |
# | misc/q             | 34.072   |
# | misc/q_est         | 34.476   |
# | misc/epsilon       | 0.1604   |
# | misc/timestep      | 22000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 152      |
# | reward/reward_max  | 152      |
# | reward/reward_min  | 152      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.50383  |
# | misc/q             | 34.623   |
# | misc/q_est         | 35.103   |
# | misc/epsilon       | 0.1595   |
# | misc/timestep      | 22500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 221.75   |
# | reward/reward_max  | 412      |
# | reward/reward_min  | 141      |
# | reward/reward_std  | 110.58   |
# | loss/bellman_error | 0.44675  |
# | misc/q             | 35.289   |
# | misc/q_est         | 35.713   |
# | misc/epsilon       | 0.1586   |
# | misc/timestep      | 23000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 131.67   |
# | reward/reward_max  | 152      |
# | reward/reward_min  | 118      |
# | reward/reward_std  | 14.659   |
# | loss/bellman_error | 0.47635  |
# | misc/q             | 35.871   |
# | misc/q_est         | 36.323   |
# | misc/epsilon       | 0.1577   |
# | misc/timestep      | 23500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 166      |
# | reward/reward_max  | 190      |
# | reward/reward_min  | 123      |
# | reward/reward_std  | 30.474   |
# | loss/bellman_error | 0.45944  |
# | misc/q             | 36.477   |
# | misc/q_est         | 36.914   |
# | misc/epsilon       | 0.1568   |
# | misc/timestep      | 24000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 155      |
# | reward/reward_max  | 172      |
# | reward/reward_min  | 131      |
# | reward/reward_std  | 17.455   |
# | loss/bellman_error | 0.46937  |
# | misc/q             | 37.05    |
# | misc/q_est         | 37.497   |
# | misc/epsilon       | 0.1559   |
# | misc/timestep      | 24500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 199.67   |
# | reward/reward_max  | 242      |
# | reward/reward_min  | 164      |
# | reward/reward_std  | 32.19    |
# | loss/bellman_error | 0.4818   |
# | misc/q             | 37.548   |
# | misc/q_est         | 38.007   |
# | misc/epsilon       | 0.155    |
# | misc/timestep      | 25000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 155.67   |
# | reward/reward_max  | 186      |
# | reward/reward_min  | 139      |
# | reward/reward_std  | 21.484   |
# | loss/bellman_error | 0.43741  |
# | misc/q             | 38.189   |
# | misc/q_est         | 38.606   |
# | misc/epsilon       | 0.1541   |
# | misc/timestep      | 25500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 160.67   |
# | reward/reward_max  | 182      |
# | reward/reward_min  | 134      |
# | reward/reward_std  | 19.956   |
# | loss/bellman_error | 0.46513  |
# | misc/q             | 38.769   |
# | misc/q_est         | 39.213   |
# | misc/epsilon       | 0.1532   |
# | misc/timestep      | 26000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 143.25   |
# | reward/reward_max  | 170      |
# | reward/reward_min  | 106      |
# | reward/reward_std  | 23.679   |
# | loss/bellman_error | 0.45556  |
# | misc/q             | 39.313   |
# | misc/q_est         | 39.748   |
# | misc/epsilon       | 0.1523   |
# | misc/timestep      | 26500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 155.67   |
# | reward/reward_max  | 185      |
# | reward/reward_min  | 140      |
# | reward/reward_std  | 20.758   |
# | loss/bellman_error | 0.51466  |
# | misc/q             | 39.82    |
# | misc/q_est         | 40.312   |
# | misc/epsilon       | 0.1514   |
# | misc/timestep      | 27000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 165.33   |
# | reward/reward_max  | 180      |
# | reward/reward_min  | 142      |
# | reward/reward_std  | 16.68    |
# | loss/bellman_error | 0.4293   |
# | misc/q             | 40.459   |
# | misc/q_est         | 40.868   |
# | misc/epsilon       | 0.1505   |
# | misc/timestep      | 27500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 125.25   |
# | reward/reward_max  | 138      |
# | reward/reward_min  | 103      |
# | reward/reward_std  | 13.255   |
# | loss/bellman_error | 0.51069  |
# | misc/q             | 40.984   |
# | misc/q_est         | 41.473   |
# | misc/epsilon       | 0.1496   |
# | misc/timestep      | 28000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 159.33   |
# | reward/reward_max  | 261      |
# | reward/reward_min  | 103      |
# | reward/reward_std  | 72.029   |
# | loss/bellman_error | 0.50324  |
# | misc/q             | 41.43    |
# | misc/q_est         | 41.911   |
# | misc/epsilon       | 0.1487   |
# | misc/timestep      | 28500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 157.67   |
# | reward/reward_max  | 187      |
# | reward/reward_min  | 132      |
# | reward/reward_std  | 22.603   |
# | loss/bellman_error | 0.47068  |
# | misc/q             | 42.03    |
# | misc/q_est         | 42.478   |
# | misc/epsilon       | 0.1478   |
# | misc/timestep      | 29000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 167.5    |
# | reward/reward_max  | 177      |
# | reward/reward_min  | 158      |
# | reward/reward_std  | 9.5      |
# | loss/bellman_error | 0.48445  |
# | misc/q             | 42.51    |
# | misc/q_est         | 42.972   |
# | misc/epsilon       | 0.1469   |
# | misc/timestep      | 29500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 245.33   |
# | reward/reward_max  | 375      |
# | reward/reward_min  | 138      |
# | reward/reward_std  | 98.035   |
# | loss/bellman_error | 0.52312  |
# | misc/q             | 42.96    |
# | misc/q_est         | 43.46    |
# | misc/epsilon       | 0.146    |
# | misc/timestep      | 30000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 204      |
# | reward/reward_max  | 238      |
# | reward/reward_min  | 170      |
# | reward/reward_std  | 34       |
# | loss/bellman_error | 0.46155  |
# | misc/q             | 43.596   |
# | misc/q_est         | 44.036   |
# | misc/epsilon       | 0.1451   |
# | misc/timestep      | 30500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 141.5    |
# | reward/reward_max  | 249      |
# | reward/reward_min  | 96       |
# | reward/reward_std  | 62.428   |
# | loss/bellman_error | 0.48599  |
# | misc/q             | 44.123   |
# | misc/q_est         | 44.588   |
# | misc/epsilon       | 0.1442   |
# | misc/timestep      | 31000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 204      |
# | reward/reward_max  | 294      |
# | reward/reward_min  | 114      |
# | reward/reward_std  | 90       |
# | loss/bellman_error | 0.45632  |
# | misc/q             | 44.695   |
# | misc/q_est         | 45.131   |
# | misc/epsilon       | 0.1433   |
# | misc/timestep      | 31500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 178.33   |
# | reward/reward_max  | 240      |
# | reward/reward_min  | 114      |
# | reward/reward_std  | 51.474   |
# | loss/bellman_error | 0.44987  |
# | misc/q             | 45.242   |
# | misc/q_est         | 45.672   |
# | misc/epsilon       | 0.1424   |
# | misc/timestep      | 32000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 144      |
# | reward/reward_max  | 173      |
# | reward/reward_min  | 124      |
# | reward/reward_std  | 19.378   |
# | loss/bellman_error | 0.51561  |
# | misc/q             | 45.679   |
# | misc/q_est         | 46.173   |
# | misc/epsilon       | 0.1415   |
# | misc/timestep      | 32500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 165.67   |
# | reward/reward_max  | 180      |
# | reward/reward_min  | 154      |
# | reward/reward_std  | 10.781   |
# | loss/bellman_error | 0.41167  |
# | misc/q             | 46.3     |
# | misc/q_est         | 46.692   |
# | misc/epsilon       | 0.1406   |
# | misc/timestep      | 33000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 149.67   |
# | reward/reward_max  | 211      |
# | reward/reward_min  | 114      |
# | reward/reward_std  | 43.561   |
# | loss/bellman_error | 0.43382  |
# | misc/q             | 46.665   |
# | misc/q_est         | 47.079   |
# | misc/epsilon       | 0.1397   |
# | misc/timestep      | 33500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 240      |
# | reward/reward_max  | 266      |
# | reward/reward_min  | 214      |
# | reward/reward_std  | 26       |
# | loss/bellman_error | 0.47535  |
# | misc/q             | 47.128   |
# | misc/q_est         | 47.583   |
# | misc/epsilon       | 0.1388   |
# | misc/timestep      | 34000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 142      |
# | reward/reward_max  | 156      |
# | reward/reward_min  | 125      |
# | reward/reward_std  | 11.203   |
# | loss/bellman_error | 0.43571  |
# | misc/q             | 47.579   |
# | misc/q_est         | 47.996   |
# | misc/epsilon       | 0.1379   |
# | misc/timestep      | 34500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 127      |
# | reward/reward_max  | 133      |
# | reward/reward_min  | 115      |
# | reward/reward_std  | 7.1764   |
# | loss/bellman_error | 0.47172  |
# | misc/q             | 47.899   |
# | misc/q_est         | 48.35    |
# | misc/epsilon       | 0.137    |
# | misc/timestep      | 35000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 134.25   |
# | reward/reward_max  | 158      |
# | reward/reward_min  | 111      |
# | reward/reward_std  | 17.796   |
# | loss/bellman_error | 0.41466  |
# | misc/q             | 48.458   |
# | misc/q_est         | 48.853   |
# | misc/epsilon       | 0.1361   |
# | misc/timestep      | 35500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 118.25   |
# | reward/reward_max  | 131      |
# | reward/reward_min  | 101      |
# | reward/reward_std  | 11.519   |
# | loss/bellman_error | 0.40249  |
# | misc/q             | 48.834   |
# | misc/q_est         | 49.218   |
# | misc/epsilon       | 0.1352   |
# | misc/timestep      | 36000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 113.25   |
# | reward/reward_max  | 125      |
# | reward/reward_min  | 101      |
# | reward/reward_std  | 8.4963   |
# | loss/bellman_error | 0.46293  |
# | misc/q             | 49.12    |
# | misc/q_est         | 49.563   |
# | misc/epsilon       | 0.1343   |
# | misc/timestep      | 36500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 120.5    |
# | reward/reward_max  | 135      |
# | reward/reward_min  | 109      |
# | reward/reward_std  | 10.235   |
# | loss/bellman_error | 0.40738  |
# | misc/q             | 49.498   |
# | misc/q_est         | 49.887   |
# | misc/epsilon       | 0.1334   |
# | misc/timestep      | 37000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 128.5    |
# | reward/reward_max  | 140      |
# | reward/reward_min  | 122      |
# | reward/reward_std  | 7.1589   |
# | loss/bellman_error | 0.48364  |
# | misc/q             | 49.776   |
# | misc/q_est         | 50.239   |
# | misc/epsilon       | 0.1325   |
# | misc/timestep      | 37500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 145.25   |
# | reward/reward_max  | 162      |
# | reward/reward_min  | 133      |
# | reward/reward_std  | 11.924   |
# | loss/bellman_error | 0.42331  |
# | misc/q             | 50.182   |
# | misc/q_est         | 50.587   |
# | misc/epsilon       | 0.1316   |
# | misc/timestep      | 38000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 156.33   |
# | reward/reward_max  | 188      |
# | reward/reward_min  | 127      |
# | reward/reward_std  | 24.958   |
# | loss/bellman_error | 0.41652  |
# | misc/q             | 50.646   |
# | misc/q_est         | 51.043   |
# | misc/epsilon       | 0.1307   |
# | misc/timestep      | 38500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 179.33   |
# | reward/reward_max  | 242      |
# | reward/reward_min  | 105      |
# | reward/reward_std  | 56.535   |
# | loss/bellman_error | 0.47684  |
# | misc/q             | 50.877   |
# | misc/q_est         | 51.334   |
# | misc/epsilon       | 0.1298   |
# | misc/timestep      | 39000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 151.67   |
# | reward/reward_max  | 174      |
# | reward/reward_min  | 129      |
# | reward/reward_std  | 18.373   |
# | loss/bellman_error | 0.42461  |
# | misc/q             | 51.297   |
# | misc/q_est         | 51.703   |
# | misc/epsilon       | 0.1289   |
# | misc/timestep      | 39500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 136      |
# | reward/reward_max  | 164      |
# | reward/reward_min  | 118      |
# | reward/reward_std  | 20.067   |
# | loss/bellman_error | 0.49111  |
# | misc/q             | 51.454   |
# | misc/q_est         | 51.925   |
# | misc/epsilon       | 0.128    |
# | misc/timestep      | 40000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 165      |
# | reward/reward_max  | 212      |
# | reward/reward_min  | 130      |
# | reward/reward_std  | 34.535   |
# | loss/bellman_error | 0.42983  |
# | misc/q             | 51.874   |
# | misc/q_est         | 52.285   |
# | misc/epsilon       | 0.1271   |
# | misc/timestep      | 40500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 194.67   |
# | reward/reward_max  | 260      |
# | reward/reward_min  | 145      |
# | reward/reward_std  | 48.238   |
# | loss/bellman_error | 0.46133  |
# | misc/q             | 52.333   |
# | misc/q_est         | 52.774   |
# | misc/epsilon       | 0.1262   |
# | misc/timestep      | 41000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 121.25   |
# | reward/reward_max  | 128      |
# | reward/reward_min  | 115      |
# | reward/reward_std  | 5.8041   |
# | loss/bellman_error | 0.39196  |
# | misc/q             | 52.677   |
# | misc/q_est         | 53.05    |
# | misc/epsilon       | 0.1253   |
# | misc/timestep      | 41500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 134.5    |
# | reward/reward_max  | 185      |
# | reward/reward_min  | 103      |
# | reward/reward_std  | 32.299   |
# | loss/bellman_error | 0.36786  |
# | misc/q             | 53.001   |
# | misc/q_est         | 53.35    |
# | misc/epsilon       | 0.1244   |
# | misc/timestep      | 42000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 157.67   |
# | reward/reward_max  | 242      |
# | reward/reward_min  | 96       |
# | reward/reward_std  | 61.722   |
# | loss/bellman_error | 0.44295  |
# | misc/q             | 53.155   |
# | misc/q_est         | 53.578   |
# | misc/epsilon       | 0.1235   |
# | misc/timestep      | 42500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 170.67   |
# | reward/reward_max  | 208      |
# | reward/reward_min  | 128      |
# | reward/reward_std  | 32.877   |
# | loss/bellman_error | 0.38614  |
# | misc/q             | 53.617   |
# | misc/q_est         | 53.985   |
# | misc/epsilon       | 0.1226   |
# | misc/timestep      | 43000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 194.5    |
# | reward/reward_max  | 232      |
# | reward/reward_min  | 157      |
# | reward/reward_std  | 37.5     |
# | loss/bellman_error | 0.43211  |
# | misc/q             | 53.797   |
# | misc/q_est         | 54.209   |
# | misc/epsilon       | 0.1217   |
# | misc/timestep      | 43500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 144.25   |
# | reward/reward_max  | 172      |
# | reward/reward_min  | 106      |
# | reward/reward_std  | 24.499   |
# | loss/bellman_error | 0.40091  |
# | misc/q             | 54.203   |
# | misc/q_est         | 54.585   |
# | misc/epsilon       | 0.1208   |
# | misc/timestep      | 44000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 146.25   |
# | reward/reward_max  | 168      |
# | reward/reward_min  | 124      |
# | reward/reward_std  | 16.437   |
# | loss/bellman_error | 0.45367  |
# | misc/q             | 54.327   |
# | misc/q_est         | 54.76    |
# | misc/epsilon       | 0.1199   |
# | misc/timestep      | 44500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 132      |
# | reward/reward_max  | 148      |
# | reward/reward_min  | 121      |
# | reward/reward_std  | 11.576   |
# | loss/bellman_error | 0.38899  |
# | misc/q             | 54.714   |
# | misc/q_est         | 55.083   |
# | misc/epsilon       | 0.119    |
# | misc/timestep      | 45000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 130.25   |
# | reward/reward_max  | 153      |
# | reward/reward_min  | 112      |
# | reward/reward_std  | 15.722   |
# | loss/bellman_error | 0.38873  |
# | misc/q             | 55.03    |
# | misc/q_est         | 55.4     |
# | misc/epsilon       | 0.1181   |
# | misc/timestep      | 45500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 167.67   |
# | reward/reward_max  | 211      |
# | reward/reward_min  | 125      |
# | reward/reward_std  | 35.113   |
# | loss/bellman_error | 0.41482  |
# | misc/q             | 55.17    |
# | misc/q_est         | 55.564   |
# | misc/epsilon       | 0.1172   |
# | misc/timestep      | 46000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 141.25   |
# | reward/reward_max  | 162      |
# | reward/reward_min  | 101      |
# | reward/reward_std  | 23.679   |
# | loss/bellman_error | 0.39178  |
# | misc/q             | 55.501   |
# | misc/q_est         | 55.872   |
# | misc/epsilon       | 0.1163   |
# | misc/timestep      | 46500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 158.33   |
# | reward/reward_max  | 175      |
# | reward/reward_min  | 127      |
# | reward/reward_std  | 22.171   |
# | loss/bellman_error | 0.36134  |
# | misc/q             | 55.645   |
# | misc/q_est         | 55.986   |
# | misc/epsilon       | 0.1154   |
# | misc/timestep      | 47000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 150      |
# | reward/reward_max  | 178      |
# | reward/reward_min  | 130      |
# | reward/reward_std  | 20.396   |
# | loss/bellman_error | 0.36263  |
# | misc/q             | 55.876   |
# | misc/q_est         | 56.219   |
# | misc/epsilon       | 0.1145   |
# | misc/timestep      | 47500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 227      |
# | reward/reward_max  | 307      |
# | reward/reward_min  | 147      |
# | reward/reward_std  | 80       |
# | loss/bellman_error | 0.32014  |
# | misc/q             | 56.04    |
# | misc/q_est         | 56.341   |
# | misc/epsilon       | 0.1136   |
# | misc/timestep      | 48000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 137.25   |
# | reward/reward_max  | 147      |
# | reward/reward_min  | 131      |
# | reward/reward_std  | 6.0156   |
# | loss/bellman_error | 0.34245  |
# | misc/q             | 56.1     |
# | misc/q_est         | 56.424   |
# | misc/epsilon       | 0.1127   |
# | misc/timestep      | 48500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 114.6    |
# | reward/reward_max  | 156      |
# | reward/reward_min  | 24       |
# | reward/reward_std  | 47.225   |
# | loss/bellman_error | 0.37921  |
# | misc/q             | 56.322   |
# | misc/q_est         | 56.68    |
# | misc/epsilon       | 0.1118   |
# | misc/timestep      | 49000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 123.67   |
# | reward/reward_max  | 147      |
# | reward/reward_min  | 83       |
# | reward/reward_std  | 28.86    |
# | loss/bellman_error | 0.38068  |
# | misc/q             | 56.663   |
# | misc/q_est         | 57.021   |
# | misc/epsilon       | 0.1109   |
# | misc/timestep      | 49500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 164.67   |
# | reward/reward_max  | 187      |
# | reward/reward_min  | 130      |
# | reward/reward_std  | 24.851   |
# | loss/bellman_error | 0.35244  |
# | misc/q             | 56.804   |
# | misc/q_est         | 57.132   |
# | misc/epsilon       | 0.11     |
# | misc/timestep      | 50000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 140.75   |
# | reward/reward_max  | 158      |
# | reward/reward_min  | 124      |
# | reward/reward_std  | 13.442   |
# | loss/bellman_error | 0.33799  |
# | misc/q             | 56.96    |
# | misc/q_est         | 57.273   |
# | misc/epsilon       | 0.1091   |
# | misc/timestep      | 50500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 180.67   |
# | reward/reward_max  | 261      |
# | reward/reward_min  | 129      |
# | reward/reward_std  | 57.575   |
# | loss/bellman_error | 0.27444  |
# | misc/q             | 57.108   |
# | misc/q_est         | 57.357   |
# | misc/epsilon       | 0.1082   |
# | misc/timestep      | 51000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 159.33   |
# | reward/reward_max  | 197      |
# | reward/reward_min  | 121      |
# | reward/reward_std  | 31.03    |
# | loss/bellman_error | 0.29496  |
# | misc/q             | 56.963   |
# | misc/q_est         | 57.223   |
# | misc/epsilon       | 0.1073   |
# | misc/timestep      | 51500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 184      |
# | reward/reward_max  | 237      |
# | reward/reward_min  | 153      |
# | reward/reward_std  | 37.656   |
# | loss/bellman_error | 0.28369  |
# | misc/q             | 57.48    |
# | misc/q_est         | 57.733   |
# | misc/epsilon       | 0.1064   |
# | misc/timestep      | 52000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 188      |
# | reward/reward_max  | 225      |
# | reward/reward_min  | 151      |
# | reward/reward_std  | 37       |
# | loss/bellman_error | 0.21781  |
# | misc/q             | 57.502   |
# | misc/q_est         | 57.682   |
# | misc/epsilon       | 0.1055   |
# | misc/timestep      | 52500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 148.75   |
# | reward/reward_max  | 163      |
# | reward/reward_min  | 130      |
# | reward/reward_std  | 13.827   |
# | loss/bellman_error | 0.1286   |
# | misc/q             | 57.431   |
# | misc/q_est         | 57.527   |
# | misc/epsilon       | 0.1046   |
# | misc/timestep      | 53000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 129      |
# | reward/reward_max  | 135      |
# | reward/reward_min  | 117      |
# | reward/reward_std  | 7.0711   |
# | loss/bellman_error | 0.16047  |
# | misc/q             | 57.462   |
# | misc/q_est         | 57.585   |
# | misc/epsilon       | 0.1037   |
# | misc/timestep      | 53500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 184.5    |
# | reward/reward_max  | 220      |
# | reward/reward_min  | 149      |
# | reward/reward_std  | 35.5     |
# | loss/bellman_error | 0.10639  |
# | misc/q             | 57.505   |
# | misc/q_est         | 57.568   |
# | misc/epsilon       | 0.1028   |
# | misc/timestep      | 54000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 162.25   |
# | reward/reward_max  | 212      |
# | reward/reward_min  | 112      |
# | reward/reward_std  | 48.282   |
# | loss/bellman_error | 0.15204  |
# | misc/q             | 57.427   |
# | misc/q_est         | 57.526   |
# | misc/epsilon       | 0.1019   |
# | misc/timestep      | 54500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 121.75   |
# | reward/reward_max  | 155      |
# | reward/reward_min  | 104      |
# | reward/reward_std  | 20.08    |
# | loss/bellman_error | 0.15281  |
# | misc/q             | 57.543   |
# | misc/q_est         | 57.625   |
# | misc/epsilon       | 0.101    |
# | misc/timestep      | 55000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 117      |
# | reward/reward_max  | 131      |
# | reward/reward_min  | 107      |
# | reward/reward_std  | 8.7178   |
# | loss/bellman_error | 0.1445   |
# | misc/q             | 57.488   |
# | misc/q_est         | 57.561   |
# | misc/epsilon       | 0.1001   |
# | misc/timestep      | 55500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 211      |
# | reward/reward_max  | 229      |
# | reward/reward_min  | 193      |
# | reward/reward_std  | 18       |
# | loss/bellman_error | 0.13423  |
# | misc/q             | 57.432   |
# | misc/q_est         | 57.475   |
# | misc/epsilon       | 0.0992   |
# | misc/timestep      | 56000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 148      |
# | reward/reward_max  | 211      |
# | reward/reward_min  | 106      |
# | reward/reward_std  | 39.045   |
# | loss/bellman_error | 0.12803  |
# | misc/q             | 57.635   |
# | misc/q_est         | 57.673   |
# | misc/epsilon       | 0.0983   |
# | misc/timestep      | 56500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 183.5    |
# | reward/reward_max  | 215      |
# | reward/reward_min  | 152      |
# | reward/reward_std  | 31.5     |
# | loss/bellman_error | 0.15294  |
# | misc/q             | 57.658   |
# | misc/q_est         | 57.725   |
# | misc/epsilon       | 0.0974   |
# | misc/timestep      | 57000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 135.4    |
# | reward/reward_max  | 185      |
# | reward/reward_min  | 106      |
# | reward/reward_std  | 31.155   |
# | loss/bellman_error | 0.12237  |
# | misc/q             | 57.692   |
# | misc/q_est         | 57.712   |
# | misc/epsilon       | 0.0965   |
# | misc/timestep      | 57500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 135.67   |
# | reward/reward_max  | 155      |
# | reward/reward_min  | 113      |
# | reward/reward_std  | 17.308   |
# | loss/bellman_error | 0.13974  |
# | misc/q             | 57.579   |
# | misc/q_est         | 57.602   |
# | misc/epsilon       | 0.0956   |
# | misc/timestep      | 58000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 211.5    |
# | reward/reward_max  | 266      |
# | reward/reward_min  | 157      |
# | reward/reward_std  | 54.5     |
# | loss/bellman_error | 0.15076  |
# | misc/q             | 57.794   |
# | misc/q_est         | 57.822   |
# | misc/epsilon       | 0.0947   |
# | misc/timestep      | 58500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 210.33   |
# | reward/reward_max  | 251      |
# | reward/reward_min  | 178      |
# | reward/reward_std  | 30.379   |
# | loss/bellman_error | 0.14356  |
# | misc/q             | 57.937   |
# | misc/q_est         | 57.948   |
# | misc/epsilon       | 0.0938   |
# | misc/timestep      | 59000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 228      |
# | reward/reward_max  | 228      |
# | reward/reward_min  | 228      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.15634  |
# | misc/q             | 57.691   |
# | misc/q_est         | 57.696   |
# | misc/epsilon       | 0.0929   |
# | misc/timestep      | 59500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 376      |
# | reward/reward_max  | 495      |
# | reward/reward_min  | 257      |
# | reward/reward_std  | 119      |
# | loss/bellman_error | 0.17997  |
# | misc/q             | 57.81    |
# | misc/q_est         | 57.854   |
# | misc/epsilon       | 0.092    |
# | misc/timestep      | 60000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 253.5    |
# | reward/reward_max  | 288      |
# | reward/reward_min  | 219      |
# | reward/reward_std  | 34.5     |
# | loss/bellman_error | 0.11175  |
# | misc/q             | 57.937   |
# | misc/q_est         | 57.927   |
# | misc/epsilon       | 0.0911   |
# | misc/timestep      | 60500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.13512  |
# | misc/q             | 57.794   |
# | misc/q_est         | 57.817   |
# | misc/epsilon       | 0.0902   |
# | misc/timestep      | 61000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 137.5    |
# | reward/reward_max  | 148      |
# | reward/reward_min  | 127      |
# | reward/reward_std  | 10.5     |
# | loss/bellman_error | 0.17863  |
# | misc/q             | 57.902   |
# | misc/q_est         | 57.926   |
# | misc/epsilon       | 0.0893   |
# | misc/timestep      | 61500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 253.67   |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 129      |
# | reward/reward_std  | 174.19   |
# | loss/bellman_error | 0.16306  |
# | misc/q             | 58.093   |
# | misc/q_est         | 58.087   |
# | misc/epsilon       | 0.0884   |
# | misc/timestep      | 62000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 137.33   |
# | reward/reward_max  | 170      |
# | reward/reward_min  | 112      |
# | reward/reward_std  | 24.24    |
# | loss/bellman_error | 0.1602   |
# | misc/q             | 58.417   |
# | misc/q_est         | 58.396   |
# | misc/epsilon       | 0.0875   |
# | misc/timestep      | 62500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 123.25   |
# | reward/reward_max  | 128      |
# | reward/reward_min  | 121      |
# | reward/reward_std  | 2.8614   |
# | loss/bellman_error | 0.17201  |
# | misc/q             | 58.482   |
# | misc/q_est         | 58.5     |
# | misc/epsilon       | 0.0866   |
# | misc/timestep      | 63000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 139.75   |
# | reward/reward_max  | 146      |
# | reward/reward_min  | 132      |
# | reward/reward_std  | 5.1174   |
# | loss/bellman_error | 0.1932   |
# | misc/q             | 58.639   |
# | misc/q_est         | 58.671   |
# | misc/epsilon       | 0.0857   |
# | misc/timestep      | 63500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 133.25   |
# | reward/reward_max  | 148      |
# | reward/reward_min  | 125      |
# | reward/reward_std  | 8.7856   |
# | loss/bellman_error | 0.20428  |
# | misc/q             | 59.584   |
# | misc/q_est         | 59.615   |
# | misc/epsilon       | 0.0848   |
# | misc/timestep      | 64000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 115.25   |
# | reward/reward_max  | 121      |
# | reward/reward_min  | 111      |
# | reward/reward_std  | 4.3804   |
# | loss/bellman_error | 0.17782  |
# | misc/q             | 59.441   |
# | misc/q_est         | 59.403   |
# | misc/epsilon       | 0.0839   |
# | misc/timestep      | 64500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 123.5    |
# | reward/reward_max  | 140      |
# | reward/reward_min  | 107      |
# | reward/reward_std  | 11.715   |
# | loss/bellman_error | 0.17151  |
# | misc/q             | 60.215   |
# | misc/q_est         | 60.222   |
# | misc/epsilon       | 0.083    |
# | misc/timestep      | 65000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 127.25   |
# | reward/reward_max  | 149      |
# ...
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.17891  |
# | misc/q             | 70.072   |
# | misc/q_est         | 70.231   |
# | misc/epsilon       | 0.0578   |
# | misc/timestep      | 79000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.19313  |
# | misc/q             | 70.18    |
# | misc/q_est         | 70.352   |
# | misc/epsilon       | 0.0569   |
# | misc/timestep      | 79500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.18723  |
# | misc/q             | 70.611   |
# | misc/q_est         | 70.78    |
# | misc/epsilon       | 0.056    |
# | misc/timestep      | 80000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.16656  |
# | misc/q             | 70.932   |
# | misc/q_est         | 71.08    |
# | misc/epsilon       | 0.0551   |
# | misc/timestep      | 80500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.16587  |
# | misc/q             | 71.157   |
# | misc/q_est         | 71.306   |
# | misc/epsilon       | 0.0542   |
# | misc/timestep      | 81000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.18966  |
# | misc/q             | 71.539   |
# | misc/q_est         | 71.714   |
# | misc/epsilon       | 0.0533   |
# | misc/timestep      | 81500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.15246  |
# | misc/q             | 71.63    |
# | misc/q_est         | 71.765   |
# | misc/epsilon       | 0.0524   |
# | misc/timestep      | 82000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.21524  |
# | misc/q             | 71.898   |
# | misc/q_est         | 72.095   |
# | misc/epsilon       | 0.0515   |
# | misc/timestep      | 82500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.19644  |
# | misc/q             | 72.156   |
# | misc/q_est         | 72.336   |
# | misc/epsilon       | 0.0506   |
# | misc/timestep      | 83000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.17649  |
# | misc/q             | 72.556   |
# | misc/q_est         | 72.716   |
# | misc/epsilon       | 0.0497   |
# | misc/timestep      | 83500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.19031  |
# | misc/q             | 72.871   |
# | misc/q_est         | 73.044   |
# | misc/epsilon       | 0.0488   |
# | misc/timestep      | 84000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.2115   |
# | misc/q             | 73.157   |
# | misc/q_est         | 73.351   |
# | misc/epsilon       | 0.0479   |
# | misc/timestep      | 84500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.17678  |
# | misc/q             | 73.29    |
# | misc/q_est         | 73.448   |
# | misc/epsilon       | 0.047    |
# | misc/timestep      | 85000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.18087  |
# | misc/q             | 73.734   |
# | misc/q_est         | 73.898   |
# | misc/epsilon       | 0.0461   |
# | misc/timestep      | 85500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.23824  |
# | misc/q             | 73.913   |
# | misc/q_est         | 74.132   |
# | misc/epsilon       | 0.0452   |
# | misc/timestep      | 86000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.14277  |
# | misc/q             | 74.37    |
# | misc/q_est         | 74.498   |
# | misc/epsilon       | 0.0443   |
# | misc/timestep      | 86500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.21012  |
# | misc/q             | 74.46    |
# | misc/q_est         | 74.656   |
# | misc/epsilon       | 0.0434   |
# | misc/timestep      | 87000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.22915  |
# | misc/q             | 74.562   |
# | misc/q_est         | 74.777   |
# | misc/epsilon       | 0.0425   |
# | misc/timestep      | 87500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.20191  |
# | misc/q             | 75.078   |
# | misc/q_est         | 75.266   |
# | misc/epsilon       | 0.0416   |
# | misc/timestep      | 88000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.17861  |
# | misc/q             | 75.18    |
# | misc/q_est         | 75.343   |
# | misc/epsilon       | 0.0407   |
# | misc/timestep      | 88500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.192    |
# | misc/q             | 75.612   |
# | misc/q_est         | 75.789   |
# | misc/epsilon       | 0.0398   |
# | misc/timestep      | 89000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.19435  |
# | misc/q             | 75.835   |
# | misc/q_est         | 76.013   |
# | misc/epsilon       | 0.0389   |
# | misc/timestep      | 89500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 363      |
# | reward/reward_max  | 363      |
# | reward/reward_min  | 363      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.17797  |
# | misc/q             | 76.083   |
# | misc/q_est         | 76.246   |
# | misc/epsilon       | 0.038    |
# | misc/timestep      | 90000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 446      |
# | reward/reward_max  | 446      |
# | reward/reward_min  | 446      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.1578   |
# | misc/q             | 76.253   |
# | misc/q_est         | 76.396   |
# | misc/epsilon       | 0.0371   |
# | misc/timestep      | 90500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.21653  |
# | misc/q             | 76.571   |
# | misc/q_est         | 76.768   |
# | misc/epsilon       | 0.0362   |
# | misc/timestep      | 91000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.15441  |
# | misc/q             | 76.967   |
# | misc/q_est         | 77.106   |
# | misc/epsilon       | 0.0353   |
# | misc/timestep      | 91500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.16129  |
# | misc/q             | 77.387   |
# | misc/q_est         | 77.534   |
# | misc/epsilon       | 0.0344   |
# | misc/timestep      | 92000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.21181  |
# | misc/q             | 77.488   |
# | misc/q_est         | 77.683   |
# | misc/epsilon       | 0.0335   |
# | misc/timestep      | 92500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.21686  |
# | misc/q             | 77.819   |
# | misc/q_est         | 78.018   |
# | misc/epsilon       | 0.0326   |
# | misc/timestep      | 93000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.16696  |
# | misc/q             | 78.6     |
# | misc/q_est         | 78.751   |
# | misc/epsilon       | 0.0317   |
# | misc/timestep      | 93500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.18257  |
# | misc/q             | 78.811   |
# | misc/q_est         | 78.977   |
# | misc/epsilon       | 0.0308   |
# | misc/timestep      | 94000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.18698  |
# | misc/q             | 79.049   |
# | misc/q_est         | 79.219   |
# | misc/epsilon       | 0.0299   |
# | misc/timestep      | 94500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.16702  |
# | misc/q             | 79.549   |
# | misc/q_est         | 79.7     |
# | misc/epsilon       | 0.029    |
# | misc/timestep      | 95000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.16664  |
# | misc/q             | 80.239   |
# | misc/q_est         | 80.39    |
# | misc/epsilon       | 0.0281   |
# | misc/timestep      | 95500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.17259  |
# | misc/q             | 80.518   |
# | misc/q_est         | 80.671   |
# | misc/epsilon       | 0.0272   |
# | misc/timestep      | 96000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.17263  |
# | misc/q             | 80.889   |
# | misc/q_est         | 81.046   |
# | misc/epsilon       | 0.0263   |
# | misc/timestep      | 96500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.15899  |
# | misc/q             | 81.177   |
# | misc/q_est         | 81.321   |
# | misc/epsilon       | 0.0254   |
# | misc/timestep      | 97000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.17413  |
# | misc/q             | 81.51    |
# | misc/q_est         | 81.67    |
# | misc/epsilon       | 0.0245   |
# | misc/timestep      | 97500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.16949  |
# | misc/q             | 82.093   |
# | misc/q_est         | 82.249   |
# | misc/epsilon       | 0.0236   |
# | misc/timestep      | 98000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.19975  |
# | misc/q             | 82.71    |
# | misc/q_est         | 82.897   |
# | misc/epsilon       | 0.0227   |
# | misc/timestep      | 98500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.20291  |
# | misc/q             | 82.725   |
# | misc/q_est         | 82.913   |
# | misc/epsilon       | 0.0218   |
# | misc/timestep      | 99000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 500      |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 500      |
# | reward/reward_std  | 0        |
# | loss/bellman_error | 0.19838  |
# | misc/q             | 83.337   |
# | misc/q_est         | 83.524   |
# | misc/epsilon       | 0.0209   |
# | misc/timestep      | 99500    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 237.67   |
# | reward/reward_max  | 500      |
# | reward/reward_min  | 71       |
# | reward/reward_std  | 187.75   |
# | loss/bellman_error | 0.18544  |
# | misc/q             | 83.582   |
# | misc/q_est         | 83.753   |
# | misc/epsilon       | 0.02     |
# | misc/timestep      | 1e+05    |
# ---------------------------------

# %% [markdown]
# Now, let's take a look at our learned policy in action:

# %%
env = make_env("CartPole-v1", monitor=True)
obs = env.reset()
while True:
    obs = torch.FloatTensor(obs).unsqueeze(0)
    act = agent.pick_action(obs, force_greedy=True)
    obs, rew, done, info = env.step(act)
    if done: break
env.close()

HTML(data=get_html_video_string(env.file_infix))
# Out:
# <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video></video>

# %%
def plot_progress(data, name=None):
    name = name or "Mean reward"
    plt.plot(data['misc/timestep'], data['reward/reward_mean'], label=name)
    lower = np.array(data['reward/reward_mean'] - data['reward/reward_std']).clip(-1e5, +1e5)
    upper = np.array(data['reward/reward_mean'] + data['reward/reward_std']).clip(-1e5, +1e5)
    examples = np.array(data['misc/timestep'])
    plt.fill_between(list(examples), list(lower), list(upper), color='blue', alpha=0.1)
    plt.legend(loc='best')
    plt.xlabel("Timestep")
    plt.ylabel("Reward")

# %% [markdown]
# The following cell plots a mean reward against training iterations. Note, that the agent may sometimes degrade its performance.

# %%
plt.figure(dpi=300)
df = pd.read_csv(str(log_root / "cartpole-v1" / "logs_dqn.csv"), sep=";")
plot_progress(df)

# %% [markdown]
# # LunarLander
#
# Okay, now that we're done with very simple CartPole environment, let's move to something more complicated.
#
# LunarLander is a simulation game where a player has to control the capsule and land it on the zone marked with flags. If an agent achieves more than 200 scores, the environment is said to be solved.
#
# ##### First, you should install Box2D support in Gym:

# %%
# !pip install 'gym[box2d]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://andrii.tytarenko%40ringteam.com:****@artifactory.svc.ring.com/api/pypi/pypi-local/simple
# Requirement already satisfied: gym[box2d] in ./venv/lib/python3.8/site-packages (0.15.3)
# Requirement already satisfied: scipy in ./venv/lib/python3.8/site-packages (from gym[box2d]) (1.9.1)
# Requirement already satisfied: six in ./venv/lib/python3.8/site-packages (from gym[box2d]) (1.16.0)
# Requirement already satisfied: cloudpickle~=1.2.0 in ./venv/lib/python3.8/site-packages (from gym[box2d]) (1.2.2)
# Requirement already satisfied: numpy>=1.10.4 in ./venv/lib/python3.8/site-packages (from gym[box2d]) (1.23.3)
# Requirement already satisfied: pyglet<=1.3.2,>=1.2.0 in ./venv/lib/python3.8/site-packages (from gym[box2d]) (1.3.2)
# Collecting box2d-py~=2.3.5; extra == "box2d"
#   Using cached box2d-py-2.3.8.tar.gz (374 kB)
# Requirement already satisfied: future in ./venv/lib/python3.8/site-packages (from pyglet<=1.3.2,>=1.2.0->gym[box2d]) (0.18.2)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp38-cp38-linux_x86_64.whl size=2806445 sha256=c14362c73ba8f9f8aff7c8ecaedd4d5112ab82795a5aa127d9bf503ad6a58fd2
#   Stored in directory: /home/andriitytarenko/snap/alacritty/common/.cache/pip/wheels/cc/4f/d6/44eb0a9e6fea384e58f19cb0c4125e46a23af2b33fe3a7e81c
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8

# %% [markdown]
# ##### The random policy quickly fails the task:

# %%
env = make_env("LunarLander-v2", monitor=True)
env.reset()
while True:
    action = env.action_space.sample()
    if env.step(action)[2]: break
env.close()

HTML(data=get_html_video_string(env.file_infix))
# Out:
# <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video></video>

# %% [markdown]
# #### Task 3: Play a bit with hyperparameters. You have to gain some intuition about what each of them does. You have to achieve mean score of 200 in ~200 000 iterations

# %%
env = make_env("LunarLander-v2", SEED)

value_network = get_network("mlp")(
    env.observation_space.shape[0],
    256,
    env.action_space.n)

agent = DQN(
    value_network,
    env.action_space,
    eps=.5,
    eps_decay=(.5 - .02) / 10**5 / 2,
    batch_size=64,
    learning_rate=8e-4,
    discount_factor=.99
)

# %%
agent = train(
    agent,
    env,
    log_dir=log_root / "lunarlander-v2",
    prefix="_dqn",
    buffer_size=10**5,
    n_steps=2*10**5,
    warmup_steps=10000,
    target_update_every=500,
    log_every=4000,
    save_every=1000
)
# Out:
# ---------------------------------
# | reward/reward_mean | -172.19  |
# | reward/reward_max  | 272.55   |
# | reward/reward_min  | -543.57  |
# | reward/reward_std  | 122.63   |
# | loss/bellman_error | 6.5301   |
# | misc/q             | 12.971   |
# | misc/q_est         | 10.668   |
# | misc/epsilon       | 0.1723   |
# | misc/timestep      | 12000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 98.026   |
# | reward/reward_max  | 235.73   |
# | reward/reward_min  | -43.94   |
# | reward/reward_std  | 112.47   |
# | loss/bellman_error | 5.0981   |
# | misc/q             | 19.134   |
# | misc/q_est         | 17.389   |
# | misc/epsilon       | 0.1627   |
# | misc/timestep      | 16000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 128.78   |
# | reward/reward_max  | 244.82   |
# | reward/reward_min  | 22.447   |
# | reward/reward_std  | 83.483   |
# | loss/bellman_error | 4.1854   |
# | misc/q             | 22.555   |
# | misc/q_est         | 21.123   |
# | misc/epsilon       | 0.1531   |
# | misc/timestep      | 20000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 157.61   |
# | reward/reward_max  | 270.06   |
# | reward/reward_min  | -10.893  |
# | reward/reward_std  | 107.46   |
# | loss/bellman_error | 3.6161   |
# | misc/q             | 24.57    |
# | misc/q_est         | 23.348   |
# | misc/epsilon       | 0.1435   |
# | misc/timestep      | 24000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 195.18   |
# | reward/reward_max  | 291.95   |
# | reward/reward_min  | -40.981  |
# | reward/reward_std  | 109.78   |
# | loss/bellman_error | 3.4128   |
# | misc/q             | 25.346   |
# | misc/q_est         | 24.156   |
# | misc/epsilon       | 0.1339   |
# | misc/timestep      | 28000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 122.8    |
# | reward/reward_max  | 257.89   |
# | reward/reward_min  | -19.36   |
# | reward/reward_std  | 105.22   |
# | loss/bellman_error | 3.0992   |
# | misc/q             | 25.399   |
# | misc/q_est         | 24.398   |
# | misc/epsilon       | 0.1243   |
# | misc/timestep      | 32000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 172.36   |
# | reward/reward_max  | 274.5    |
# | reward/reward_min  | -85.981  |
# | reward/reward_std  | 129.49   |
# | loss/bellman_error | 2.9709   |
# | misc/q             | 24.718   |
# | misc/q_est         | 23.669   |
# | misc/epsilon       | 0.1147   |
# | misc/timestep      | 36000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 219.84   |
# | reward/reward_max  | 256.37   |
# | reward/reward_min  | 128.32   |
# | reward/reward_std  | 42.457   |
# | loss/bellman_error | 2.6817   |
# | misc/q             | 24.373   |
# | misc/q_est         | 23.604   |
# | misc/epsilon       | 0.1051   |
# | misc/timestep      | 40000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 131.07   |
# | reward/reward_max  | 292.37   |
# | reward/reward_min  | 57.348   |
# | reward/reward_std  | 95.131   |
# | loss/bellman_error | 2.5572   |
# | misc/q             | 23.557   |
# | misc/q_est         | 22.886   |
# | misc/epsilon       | 0.095504 |
# | misc/timestep      | 44000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 100.66   |
# | reward/reward_max  | 188.87   |
# | reward/reward_min  | 56.797   |
# | reward/reward_std  | 53.89    |
# | loss/bellman_error | 2.4177   |
# | misc/q             | 23.486   |
# | misc/q_est         | 22.718   |
# | misc/epsilon       | 0.085904 |
# | misc/timestep      | 48000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 80.682   |
# | reward/reward_max  | 177.31   |
# | reward/reward_min  | -12.899  |
# | reward/reward_std  | 88.738   |
# | loss/bellman_error | 2.2748   |
# | misc/q             | 22.596   |
# | misc/q_est         | 21.905   |
# | misc/epsilon       | 0.076304 |
# | misc/timestep      | 52000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 104.87   |
# | reward/reward_max  | 219.65   |
# | reward/reward_min  | 3.7152   |
# | reward/reward_std  | 77.738   |
# | loss/bellman_error | 2.2866   |
# | misc/q             | 21.246   |
# | misc/q_est         | 20.508   |
# | misc/epsilon       | 0.066704 |
# | misc/timestep      | 56000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 16.449   |
# | reward/reward_max  | 45.962   |
# | reward/reward_min  | 3.6309   |
# | reward/reward_std  | 17.14    |
# | loss/bellman_error | 2.1086   |
# | misc/q             | 20.75    |
# | misc/q_est         | 20.12    |
# | misc/epsilon       | 0.057104 |
# | misc/timestep      | 60000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 138.79   |
# | reward/reward_max  | 244.11   |
# | reward/reward_min  | -37.278  |
# | reward/reward_std  | 111.56   |
# | loss/bellman_error | 2.0192   |
# | misc/q             | 20.203   |
# | misc/q_est         | 19.626   |
# | misc/epsilon       | 0.047504 |
# | misc/timestep      | 64000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 219.6    |
# | reward/reward_max  | 254.95   |
# | reward/reward_min  | 169.88   |
# | reward/reward_std  | 33.579   |
# | loss/bellman_error | 2.0059   |
# | misc/q             | 19.177   |
# | misc/q_est         | 18.579   |
# | misc/epsilon       | 0.037904 |
# | misc/timestep      | 68000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 196.2    |
# | reward/reward_max  | 266.22   |
# | reward/reward_min  | 84.699   |
# | reward/reward_std  | 56.363   |
# | loss/bellman_error | 1.9574   |
# | misc/q             | 18.078   |
# | misc/q_est         | 17.439   |
# | misc/epsilon       | 0.028304 |
# | misc/timestep      | 72000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 127.23   |
# | reward/reward_max  | 245.71   |
# | reward/reward_min  | -58.022  |
# | reward/reward_std  | 127.97   |
# | loss/bellman_error | 1.7637   |
# | misc/q             | 17.708   |
# | misc/q_est         | 17.125   |
# | misc/epsilon       | 0.018704 |
# | misc/timestep      | 76000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 130.16   |
# | reward/reward_max  | 248.05   |
# | reward/reward_min  | -62.508  |
# | reward/reward_std  | 124.42   |
# | loss/bellman_error | 1.8021   |
# | misc/q             | 17.78    |
# | misc/q_est         | 17.105   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 80000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 92.483   |
# | reward/reward_max  | 237.23   |
# | reward/reward_min  | -73.714  |
# | reward/reward_std  | 124.93   |
# | loss/bellman_error | 1.702    |
# | misc/q             | 17.272   |
# | misc/q_est         | 16.651   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 84000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 64.958   |
# | reward/reward_max  | 271.62   |
# | reward/reward_min  | -64.337  |
# | reward/reward_std  | 123.74   |
# | loss/bellman_error | 1.6637   |
# | misc/q             | 16.154   |
# | misc/q_est         | 15.68    |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 88000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 99.292   |
# | reward/reward_max  | 236.42   |
# | reward/reward_min  | -107.26  |
# | reward/reward_std  | 123.94   |
# | loss/bellman_error | 1.6124   |
# | misc/q             | 15.77    |
# | misc/q_est         | 15.22    |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 92000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 111.55   |
# | reward/reward_max  | 264.66   |
# | reward/reward_min  | -36.765  |
# | reward/reward_std  | 135.73   |
# | loss/bellman_error | 1.7319   |
# | misc/q             | 14.583   |
# | misc/q_est         | 13.983   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 96000    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 15.56    |
# | reward/reward_max  | 126.43   |
# | reward/reward_min  | -81.754  |
# | reward/reward_std  | 76.192   |
# | loss/bellman_error | 1.6579   |
# | misc/q             | 13.541   |
# | misc/q_est         | 12.999   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1e+05    |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 190.87   |
# | reward/reward_max  | 281.99   |
# | reward/reward_min  | 77.927   |
# | reward/reward_std  | 86.52    |
# | loss/bellman_error | 1.4573   |
# | misc/q             | 14.205   |
# | misc/q_est         | 13.793   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.04e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 132.71   |
# | reward/reward_max  | 237.4    |
# | reward/reward_min  | -21.336  |
# | reward/reward_std  | 89.901   |
# | loss/bellman_error | 1.1814   |
# | misc/q             | 15.094   |
# | misc/q_est         | 14.728   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.08e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 210.11   |
# | reward/reward_max  | 264.21   |
# | reward/reward_min  | 128.82   |
# | reward/reward_std  | 52.002   |
# | loss/bellman_error | 0.65944  |
# | misc/q             | 17.423   |
# | misc/q_est         | 17.293   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.12e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 128.46   |
# | reward/reward_max  | 241.04   |
# | reward/reward_min  | -7.1434  |
# | reward/reward_std  | 81.958   |
# | loss/bellman_error | 0.54386  |
# | misc/q             | 17.596   |
# | misc/q_est         | 17.518   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.16e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 169.19   |
# | reward/reward_max  | 280.02   |
# | reward/reward_min  | 48.8     |
# | reward/reward_std  | 100.39   |
# | loss/bellman_error | 0.51052  |
# | misc/q             | 17.128   |
# | misc/q_est         | 17.028   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.2e+05  |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 180.77   |
# | reward/reward_max  | 264.07   |
# | reward/reward_min  | 14.447   |
# | reward/reward_std  | 87.555   |
# | loss/bellman_error | 0.503    |
# | misc/q             | 16.705   |
# | misc/q_est         | 16.606   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.24e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 158.82   |
# | reward/reward_max  | 275.42   |
# | reward/reward_min  | -4.0349  |
# | reward/reward_std  | 101.63   |
# | loss/bellman_error | 0.48197  |
# | misc/q             | 16.74    |
# | misc/q_est         | 16.64    |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.28e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | -8.7248  |
# | reward/reward_max  | 277.28   |
# | reward/reward_min  | -677.52  |
# | reward/reward_std  | 347.81   |
# | loss/bellman_error | 0.46771  |
# | misc/q             | 16.213   |
# | misc/q_est         | 16.105   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.32e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 81.842   |
# | reward/reward_max  | 197.27   |
# | reward/reward_min  | -13.007  |
# | reward/reward_std  | 79.755   |
# | loss/bellman_error | 0.441    |
# | misc/q             | 15.883   |
# | misc/q_est         | 15.774   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.36e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 122.06   |
# | reward/reward_max  | 238.16   |
# | reward/reward_min  | -18.781  |
# | reward/reward_std  | 106.84   |
# | loss/bellman_error | 0.41025  |
# | misc/q             | 14.822   |
# | misc/q_est         | 14.726   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.4e+05  |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 124.18   |
# | reward/reward_max  | 201.77   |
# | reward/reward_min  | -22.498  |
# | reward/reward_std  | 86.745   |
# | loss/bellman_error | 0.36719  |
# | misc/q             | 14.184   |
# | misc/q_est         | 14.102   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.44e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 157.97   |
# | reward/reward_max  | 308.13   |
# | reward/reward_min  | -2.804   |
# | reward/reward_std  | 132.83   |
# | loss/bellman_error | 0.35761  |
# | misc/q             | 13.709   |
# | misc/q_est         | 13.615   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.48e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 109.39   |
# | reward/reward_max  | 220.06   |
# | reward/reward_min  | 1.6894   |
# | reward/reward_std  | 104.21   |
# | loss/bellman_error | 0.33537  |
# | misc/q             | 13.177   |
# | misc/q_est         | 13.088   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.52e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 39.035   |
# | reward/reward_max  | 211.08   |
# | reward/reward_min  | -42.012  |
# | reward/reward_std  | 101.49   |
# | loss/bellman_error | 0.32095  |
# | misc/q             | 12.924   |
# | misc/q_est         | 12.822   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.56e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 157.78   |
# | reward/reward_max  | 284.82   |
# | reward/reward_min  | 6.6242   |
# | reward/reward_std  | 94.717   |
# | loss/bellman_error | 0.32802  |
# | misc/q             | 12.84    |
# | misc/q_est         | 12.74    |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.6e+05  |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 44.549   |
# | reward/reward_max  | 240      |
# | reward/reward_min  | -50.632  |
# | reward/reward_std  | 115.69   |
# | loss/bellman_error | 0.33821  |
# | misc/q             | 12.746   |
# | misc/q_est         | 12.644   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.64e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 144.94   |
# | reward/reward_max  | 239.03   |
# | reward/reward_min  | -5.3669  |
# | reward/reward_std  | 98.18    |
# | loss/bellman_error | 0.32693  |
# | misc/q             | 12.268   |
# | misc/q_est         | 12.177   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.68e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 183.6    |
# | reward/reward_max  | 264.37   |
# | reward/reward_min  | 9.1064   |
# | reward/reward_std  | 87.577   |
# | loss/bellman_error | 0.33     |
# | misc/q             | 11.885   |
# | misc/q_est         | 11.792   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.72e+05 |
# ---------------------------------
# ---------------------------------
# | reward/reward_mean | 150.94   |
# | reward/reward_max  | 282.02   |
# | reward/reward_min  | -63.099  |
# | reward/reward_std  | 139.92   |
# | loss/bellman_error | 0.31645  |
# | misc/q             | 11.49    |
# | misc/q_est         | 11.397   |
# | misc/epsilon       | 0.01     |
# | misc/timestep      | 1.76e+05 |
# ---------------------------------

# %%
env = make_env("LunarLander-v2", monitor=True)
obs = env.reset()
while True:
    obs = torch.FloatTensor(obs).unsqueeze(0)
    act = agent.pick_action(obs, force_greedy=True)
    obs, rew, done, info = env.step(act)
    if done: break
env.close()

HTML(data=get_html_video_string(env.file_infix))

# %%
plt.figure(dpi=300)
df = pd.read_csv(str(log_root / "lunarlander-v2" / "logs_dqn.csv"), sep=";")
plot_progress(df)

# %% [markdown]
# ## Double DQN

# %% [markdown]
# One of the main drawbacks of vanila DQN is that it overestimates Q-values. More details could be found in the original paper. In a couple of words, we have to estimate an expecation of maximum, not a maximum of expectations as we do in vanila DQN. The trick is to use the second network for the updates (we use target network for this):
#
# $$y = r + \gamma Q_{target}(s^\prime, \text{argmax}_a Q(s^\prime, a) )$$
#
# Compared to
#
# $$y = r + \gamma Q_{target}(s^\prime, \text{argmax}_a Q_{target}(s^\prime, a) )$$
#
# from vanila DQN. Which is the same as:
#
# $$y = r + \gamma \text{max}_a Q_{target}(s^\prime, a)$$
#
# Double Q-learning paper: https://papers.nips.cc/paper/3964-double-q-learning <br>
# Double DQN paper: https://arxiv.org/abs/1509.06461
#
# #### Task 4. Implement Double DQN in `lib/agent.py`.

# %% [markdown]
#  Now, let's try it for the LunarLander environment:

# %%
env = make_env("LunarLander-v2", SEED)

value_network = get_network("mlp")(
    env.observation_space.shape[0],
    256,
    env.action_space.n)

agent = DQN(
    value_network,
    env.action_space,
    eps=.5,
    eps_decay=(.5 - .02) / 10**5 / 2,
    batch_size=64,
    learning_rate=8e-4,
    discount_factor=.99,
    double=True
)

# %%
agent = train(
    agent,
    env,
    log_dir=log_root / "lunarlander-v2",
    prefix="_double_dqn",
    buffer_size=10**5,
    n_steps=2*10**5,
    warmup_steps=10000,
    target_update_every=500,
    log_every=4000,
    save_every=1000
)

# %%
env = make_env("LunarLander-v2", monitor=True)
obs = env.reset()
while True:
    obs = torch.FloatTensor(obs).unsqueeze(0)
    act = agent.pick_action(obs, force_greedy=True)
    obs, rew, done, info = env.step(act)
    if done: break
env.close()

HTML(data=get_html_video_string(env.file_infix))

# %% [markdown]
# ### You should obtain better curve for Double DQN, however it is not always the case. For such environent the improvement could be neglectable. Although, you have to at least reach the same performance.
# ### You may want to compare the performance on _CartPole_ as, unlike _LunarLander_ , its reward function is dense. However, it may be too simple to reveal any difference.
# ### Thus, it is much better to compare DQN and Double DQN on Atari benchmark.

# %%
plt.figure(dpi=300)
df = pd.read_csv(str(log_root / "lunarlander-v2" / "logs_dqn.csv"), sep=";")
df_double = pd.read_csv(str(log_root / "lunarlander-v2" / "logs_double_dqn.csv"), sep=";")
plot_progress(df, "DQN")
plot_progress(df_double, "Double DQN")

# %% [markdown]
# ### Look at the graphs of estimated Q values by DQN and Double DQN. Could you describe what's happening?

# %%
plt.figure(dpi=300)
plt.xlabel("Timestep")
plt.ylabel("estimated Q value")
plt.plot(df['misc/timestep'], df['misc/q_est'], label="DQN")
plt.plot(df_double['misc/timestep'], df_double['misc/q_est'], label="Double DQN")
plt.legend(loc="best");

# %% [markdown]
# # ATARI [Optional]
#
# In this section, you can try the algorithm on the larger problem from Atari suit. This section is optional. The training procedure is computationally cumbersome, so that ideally one may want to use GPU and powerful CPU for this task. Also note, that usually people choose larger `buffer_size` for this benchmark, which may consume anormous amount of RAM. To avoid the memory overflow, you may consider to use lossless compression algorithm to save a lot of space by compressing observations. See RLLib or Catalyst.RL for example.
#
# If you decided to go through the task, note, that typical choice of hyperparameters for Atari differs from previous ones. See RLLib's configs, for example, as a reference.

# %%
# !pip install 'gym[atari]'
# Out:
# Requirement already satisfied: gym[atari] in ./.venv/lib/python3.7/site-packages (0.15.4)
# Requirement already satisfied: scipy in ./.venv/lib/python3.7/site-packages (from gym[atari]) (1.4.1)
# Requirement already satisfied: cloudpickle~=1.2.0 in ./.venv/lib/python3.7/site-packages (from gym[atari]) (1.2.2)
# Requirement already satisfied: numpy>=1.10.4 in ./.venv/lib/python3.7/site-packages (from gym[atari]) (1.18.1)
# Requirement already satisfied: pyglet<=1.3.2,>=1.2.0 in ./.venv/lib/python3.7/site-packages (from gym[atari]) (1.3.2)
# Requirement already satisfied: six in ./.venv/lib/python3.7/site-packages (from gym[atari]) (1.14.0)
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.7/site-packages (from gym[atari]) (4.1.2.30)
# Collecting Pillow; extra == "atari" (from gym[atari])
#   Using cached https://files.pythonhosted.org/packages/0c/43/b52847e473ac6cbd10a749b63018b2bb08b55c6e1a1923872361443906de/Pillow-7.0.0-cp37-cp37m-macosx_10_6_intel.whl
# Collecting atari-py~=0.2.0; extra == "atari" (from gym[atari])
#   Using cached https://files.pythonhosted.org/packages/f9/bb/b01e780ac5abc41f41b37faeaa005fcdabffe37713d943f86190305c8294/atari_py-0.2.6-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Requirement already satisfied: future in ./.venv/lib/python3.7/site-packages (from pyglet<=1.3.2,>=1.2.0->gym[atari]) (0.18.2)
# Installing collected packages: Pillow, atari-py
# Successfully installed Pillow-7.0.0 atari-py-0.2.6
# WARNING: You are using pip version 19.2.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# #### Clone and install `baselines` lib. We'll use atari wrappers from it.
#
# Here are commands for that:
# ```bash
# git clone https://github.com/openai/baselines
# cd baselines
# pip install -e .
# ```

# %%
from baselines.common.atari_wrappers import make_atari, wrap_deepmind
from lib.utils import TransposeImage

# %%
def make_env(name, seed=None, monitor=False):
    env = gym.make(name)

    is_atari = hasattr(gym.envs, 'atari') and isinstance(
        env.unwrapped, gym.envs.atari.atari_env.AtariEnv)

    if is_atari:
        max_epi_steps = 108000
        if max_epi_steps < 0:
            max_epi_steps = None

        env = make_atari(name, max_epi_steps)
        env = wrap_deepmind(env, True, True, True, True)
        env = TransposeImage(env, op=[2, 0, 1])
        
    if monitor:
        env = wrappers.Monitor(env, "./gym-results", force=True)
    if seed:
        env.seed(seed)


    return env

# %%
env = make_env("BreakoutNoFrameskip-v4", monitor=True)
obs = env.reset()
while True:
    act = env.action_space.sample()
    if env.step(act)[2]: break
env.close()

HTML(data=get_html_video_string(env.file_infix))
# Out:
# <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video></video>

# %%
env = make_env("BreakoutNoFrameskip-v4", SEED)

value_network = get_network("vision")(
    env.observation_space.shape[0],
    256,
    env.action_space.n)

agent = DQN(
    value_network,
    env.action_space,
    eps=.5,
    eps_decay=(.5 - .02) / 10**5 / 2,
    batch_size=64,
    learning_rate=8e-4,
    discount_factor=.99,
    double=True
)

# %%
agent = train(
    agent,
    env,
    log_dir=log_root / "breakout-v4",
    prefix="_double_dqn",
    buffer_size=10**5,
    n_steps=2*10**5,
    warmup_steps=10000,
    target_update_every=100,
    log_every=4000,
    save_every=1000
)
# Out:
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/andriitytarenko/devel/dqn/.venv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /Users/andriitytarenko/devel/dqn/lib/logging.py:103: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# ---------------------------------
# | reward/reward_mean | 0.24865  |
# | reward/reward_max  | 4        |
# | reward/reward_min  | 0        |
# | reward/reward_std  | 0.56741  |
# | loss/bellman_error | 0.003637 |
# | misc/q             | 0        |
# | misc/q_est         | 0        |
# | misc/epsilon       | 0.4712   |
# | misc/timestep      | 12000    |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-f163369f334f> in <module>
#       9     target_update_every=100,
#      10     log_every=4000,
# ---> 11     save_every=1000
#      12 )
#
# <ipython-input-7-8a56e00961e8> in train(agent, env, log_dir, prefix, buffer_size, n_steps, warmup_steps, target_update_every, log_every, save_every)
#      39         if i > warmup_steps:
#      40
# ---> 41             loss, q, q_est = agent.update_value(memory)
#      42             logger.log_arr_kv("loss/bellman_error_t", loss)
#      43             logger.log_arr_kv("loss/q_t", q)
#
# ~/devel/dqn/lib/agent.py in update_value(self, replay_buffer)
#      84             next_q = self.target_network(v_s1).detach().max(dim=1)[0]
#      85         else:
# ---> 86             a_idx = self.value_network(v_s1).detach().max(dim=1, keepdim=True)[1]
#      87             next_q = self.target_network(v_s1).detach().gather(1, a_idx).squeeze()
#      88
#
# ~/devel/dqn/.venv/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/devel/dqn/lib/network.py in forward(self, x)
#      59
#      60     def forward(self, x):
# ---> 61         x = self.feature_extractor(x)
#      62         x = self.head(x)
#      63         return x
#
# ~/devel/dqn/.venv/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/devel/dqn/.venv/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/devel/dqn/.venv/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/devel/dqn/.venv/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     343
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#     347 class Conv3d(_ConvNd):
#
# ~/devel/dqn/.venv/lib/python3.7/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     340                             _pair(0), self.dilation, self.groups)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#     344     def forward(self, input):
#
# KeyboardInterrupt:

# %%
env = make_env("BreakoutNoFrameskip-v4", monitor=True)
obs = env.reset()
while True:
    obs = torch.FloatTensor(obs).unsqueeze(0)
    act = agent.pick_action(obs, force_greedy=True)
    obs, rew, done, info = env.step(act)
    if done: break
env.close()

HTML(data=get_html_video_string(env.file_infix))

# %%
plt.figure(dpi=300)
df = pd.read_csv(str(log_root / "breakout-v4" / "logs_double_dqn.csv"), sep=";")
plot_progress(df)
